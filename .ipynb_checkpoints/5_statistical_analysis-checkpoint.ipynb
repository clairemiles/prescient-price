# %% [markdown]
# ## Statistical Analysis
#
# Now that the data is cleaned and I've conducted some preliminary analysis, it's time to enrich my exploration with inferential statistics. My exploratory data analysis will include the following steps:
#    1. Look for numerical variables in the dataset that are correlated.
#    2. Run confidence intervals and significance tests on variables that are related to the project question.
#    3. Re-evaluate the original project question based on statistical evidence.
#
# Once again, I will focus on the listings dataset in this notebook, as the listing data hosts all numerical features that the dataset currently has. The reviews data, which contains the review text for different listings, will be interpreted using NLP later on in the project process, as will other text data in the listings file.

# %%
# import relevant packages
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# remove warnings
import warnings
warnings.filterwarnings("ignore")

# set seaborn theme
sns.set(style='ticks')

# %matplotlib inline

# %%
# load listings dataset
df = pd.read_csv('/Users/limesncoconuts2/datasets/capstone_one/los_angeles/los-angeles_listings.csv')
df.head()
# Out:
#   access  accommodates  availability_30  availability_365  availability_60  \
# 0    NaN           2.0             30.0             365.0             60.0
# 1    NaN           1.0             30.0             365.0             60.0
# 2    NaN           1.0             15.0             344.0             39.0
# 3    NaN           2.0             18.0             261.0             32.0
# 4    NaN           1.0             30.0             365.0             60.0
#
#    availability_90  bathrooms  bed_type  bedrooms  beds  \
# 0             90.0        1.0  Real Bed       1.0   1.0
# 1             90.0        1.0  Real Bed       1.0   1.0
# 2             69.0        1.0     Couch       1.0   1.0
# 3             62.0        1.0  Real Bed       1.0   1.0
# 4             90.0        1.0     Futon       1.0   1.0
#
#              ...             phone_verification photographer_verification  \
# 0            ...                           True                     False
# 1            ...                           True                     False
# 2            ...                           True                     False
# 3            ...                           True                     False
# 4            ...                           True                     False
#
#   reviews_verification selfie_verification sent_id_verification  \
# 0                 True               False                False
# 1                False               False                False
# 2                 True               False                False
# 3                False               False                False
# 4                 True               False                False
#
#    sesame_verification sesame_offline_verification weibo_verification  \
# 0                False                       False              False
# 1                False                       False              False
# 2                False                       False              False
# 3                False                       False              False
# 4                False                       False              False
#
#   work_email_verification zhima_selfie_verification
# 0                   False                     False
# 1                   False                     False
# 2                   False                     False
# 3                   False                     False
# 4                   False                     False
#
# [5 rows x 316 columns]

# %% [markdown]
# This statistical analysis will focus on numerical and categorical data. The text data will be interpreted as features later on in the project process

# %%
# fix categories that didn't transfer from the data cleaning notebook?
to_category = ['property_type','room_type','bed_type','cancellation_policy','market','neighbourhood','city','state','calendar_updated','host_neighbourhood']
for col_name in to_category:
        try:
            df[col_name] = df[col_name].astype('category')
        except KeyError:
            pass

# %%
# turn boolean columns into 0 or 1 integers
for col in df:
    if df[col].dtype == 'bool':
        df[col] = df[col].astype('int64')

# %%
# cut down dataframe to include only numerical and categorical data
df = df.select_dtypes(include=['number', 'datetime', 'category'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599177 entries, 0 to 599176
# Data columns (total 59 columns):
# accommodates                        599177 non-null float64
# availability_30                     599163 non-null float64
# availability_365                    599163 non-null float64
# availability_60                     599163 non-null float64
# availability_90                     599163 non-null float64
# bathrooms                           599177 non-null float64
# bed_type                            599177 non-null category
# bedrooms                            598639 non-null float64
# beds                                598840 non-null float64
# calculated_host_listings_count      599177 non-null float64
# calendar_updated                    599177 non-null category
# cancellation_policy                 585132 non-null category
# city                                599088 non-null category
# cleaning_fee_USD                    474852 non-null float64
# extra_people_USD                    599177 non-null float64
# guests_included                     599177 non-null float64
# has_availability                    599177 non-null int64
# host_acceptance_rate_percentage     127640 non-null float64
# host_has_profile_pic                599177 non-null int64
# host_id                             599177 non-null int64
# host_identity_verified              599177 non-null int64
# host_is_superhost                   599177 non-null int64
# host_listings_count                 584891 non-null float64
# host_neighbourhood                  486561 non-null category
# host_response_rate_percentage       476785 non-null float64
# host_total_listings_count           584891 non-null float64
# id                                  599177 non-null int64
# instant_bookable                    599177 non-null int64
# is_business_travel_ready            599177 non-null int64
# is_location_exact                   599177 non-null int64
# latitude                            599177 non-null float64
# longitude                           599177 non-null float64
# market                              594083 non-null category
# maximum_nights                      599177 non-null float64
# minimum_nights                      599177 non-null float64
# monthly_price_USD                   8413 non-null float64
# neighbourhood                       524739 non-null category
# neighbourhood_group_cleansed        0 non-null float64
# number_of_reviews                   599177 non-null float64
# price_USD                           599177 non-null float64
# property_type                       599175 non-null category
# require_guest_phone_verification    599177 non-null int64
# require_guest_profile_picture       599177 non-null int64
# requires_license                    599177 non-null int64
# review_scores_accuracy              463091 non-null float64
# review_scores_checkin               462654 non-null float64
# review_scores_cleanliness           463193 non-null float64
# review_scores_communication         463231 non-null float64
# review_scores_location              462628 non-null float64
# review_scores_rating                463931 non-null float64
# review_scores_value                 462516 non-null float64
# reviews_per_month                   471868 non-null float64
# room_type                           599177 non-null category
# scrape_id                           599177 non-null float64
# security_deposit_USD                347274 non-null float64
# square_feet                         7787 non-null float64
# state                               599177 non-null category
# weekly_price_USD                    108325 non-null float64
# zipcode                             599177 non-null int64
# dtypes: category(10), float64(36), int64(13)
# memory usage: 231.5 MB

# %%
cols = ['bathrooms', 'beds', 'city', 'number_of_reviews']# 'price_USD', 'property_type',
       #'review_scores_rating', 'reviews_per_month', 'room_type', 'square_feet', 'zipcode']
sns.pairplot(df)

# %%
# heat maps between variables that are correlated - have to have unique col values in pandas index
cols = ['bathrooms', 'beds', 'cancellation_policy', 'city', 'instant_bookable',
        'host_is_superhost', 'is_business_travel_ready,', 'number_of_reviews', 'price_USD', 'property_type',
       'review_scores_rating', 'reviews_per_month', 'room_type', 'square_feet'
       , 'zipcode']

sns.heatmap(df[cols].corr(), square=True, cmap='RdYlGn')
