# %% [markdown]
# ## Data Wrangling: Data Cleaning

# %% [markdown]
# Now that the data has been sourced and consolidated, I will further clean the data and conduct some preliminary data exploration.

# %%
# import relevant packages
# %matplotlib inline

import pandas as pd
import numpy as np
import os
import time
import shutil
import matplotlib.pyplot as plt
from langdetect import detect

import warnings
warnings.filterwarnings("ignore")

# show all columns
pd.set_option('display.max_columns', None)

# %%
# establish the directory
directory = '/Users/limesncoconuts2/springboard_data/data_capstone_one/los_angeles/'

# %% [markdown]
# ### Listings Data

# %% [markdown]
# In order to keep the data tidy and to preserve vital information about the data, I will add a column called 'city_name' each time a csv file is imported to preserve the information about which city the data corresponds to.

# %%
# import listings files for Los Angeles
city = 'los-angeles'
listings = pd.read_csv(directory + city + '_listings.csv')

# %% [markdown]
# Looking at the first few rows of the dataframe will give insight into which columns could be altered to make our initial analysis easier. For example, numbers with '$' or '%' signs may be able to be converted to a numeric datatype, while columns with few unique vales could be changes into a category datatype. Additionally, if a column appears to be a categroy, it's important to inspect whether there may be small errors from the data entry process (like capitalization or spelling errors) that may impact our analysis.

# %%
listings.head()
# Out:
#   access accommodates                                          amenities  \
# 0    NaN            2  {Internet,"Wireless Internet","Air Conditionin...
# 1    NaN            1  {TV,"Cable TV",Internet,"Wireless Internet","A...
# 2    NaN            6  {TV,"Cable TV",Internet,"Wireless Internet","A...
# 3    NaN            1  {TV,"Cable TV",Internet,"Wireless Internet","A...
# 4    NaN            2  {"Cable TV",Internet,"Wireless Internet",Kitch...
#
#    availability_30 availability_365 availability_60  availability_90  \
# 0             30.0              365              60             90.0
# 1             30.0              365              60             90.0
# 2              0.0               24               0              0.0
# 3             15.0              344              39             69.0
# 4             18.0              261              32             62.0
#
#   bathrooms  bed_type bedrooms beds calculated_host_listings_count  \
# 0         1  Real Bed        1    1                              1
# 1         1  Real Bed        1    1                              1
# 2         3  Real Bed        3    4                              1
# 3         1     Couch        1    1                              2
# 4         1  Real Bed        1    1                              6
#
#   calendar_last_scraped calendar_updated cancellation_policy         city  \
# 0            2015-07-28     6 months ago            moderate      Arcadia
# 1            2015-07-28            never            flexible  Los Angeles
# 2            2015-07-28      7 weeks ago            flexible  Los Angeles
# 3            2015-07-28       3 days ago            flexible  Los Angeles
# 4            2015-07-28     3 months ago            moderate     Pasadena
#
#   cleaning_fee        country country_code date_recorded  \
# 0       $10.00  United States           US    2015-07-25
# 1          NaN  United States           US    2015-07-25
# 2      $120.00  United States           US    2015-07-25
# 3        $5.00  United States           US    2015-07-25
# 4          NaN  United States           US    2015-07-25
#
#                                          description experiences_offered  \
# 0  安靜舒適的独立大套房. 阳光明媚的大卧室，(附帶冰箱)一个超大衣帽間和浴室. 提供免费无线高...                none
# 1  Small but real clean apartment in Hancock Park...                none
# 2  Originally built in 1922, this Italian-style v...                none
# 3  Extra comfy beanbag that can easily fit two.  ...                none
# 4  If you are planning to visit our wonderful cit...                none
#
#   extra_people first_review guests_included has_availability  \
# 0       $20.00   2014-09-15               1                t
# 1        $0.00          NaN               1                t
# 2        $0.00          NaN               1                t
# 3       $15.00   2015-01-15               1                t
# 4       $10.00   2012-01-04               2                t
#
#                                           host_about host_acceptance_rate  \
# 0                                                NaN                 100%
# 1       Clean & well educated, proffessional, mature                  NaN
# 2                                                NaN                  NaN
# 3  My name is Sheerene and I live with my boyfrie...                  86%
# 4  I am a  retired school teacher, but still very...                 100%
#
#   host_has_profile_pic   host_id host_identity_verified host_is_superhost  \
# 0                    t  20130073                      f                 f
# 1                    t   8786086                      f                 f
# 2                    t  35283911                      f                 f
# 3                    t  12223017                      t                 f
# 4                    t    244186                      t                 f
#
#    host_listings_count                           host_location host_name  \
# 0                  1.0                                      PH      Cici
# 1                  1.0  Los Angeles, California, United States      Nick
# 2                  1.0                                      US     Grant
# 3                  3.0  Los Angeles, California, United States  Sheerene
# 4                  6.0     Pasadena, California, United States    Albert
#
#   host_neighbourhood                                   host_picture_url  \
# 0                NaN  https://a2.muscache.com/ac/users/20130073/prof...
# 1       Mid-Wilshire  https://a0.muscache.com/ac/users/8786086/profi...
# 2    Hollywood Hills  https://a1.muscache.com/ac/users/35283911/prof...
# 3           Westside  https://a1.muscache.com/ac/users/12223017/prof...
# 4           Pasadena  https://a1.muscache.com/ac/users/244186/profil...
#
#   host_response_rate  host_response_time  host_since  \
# 0               100%        within a day  2014-08-16
# 1                NaN                 NaN  2013-09-12
# 2               100%  within a few hours  2015-06-08
# 3                53%        within a day  2014-02-13
# 4               100%  within a few hours  2010-09-24
#
#                                   host_thumbnail_url  \
# 0  https://a2.muscache.com/ac/users/20130073/prof...
# 1  https://a0.muscache.com/ac/users/8786086/profi...
# 2  https://a1.muscache.com/ac/users/35283911/prof...
# 3  https://a1.muscache.com/ac/users/12223017/prof...
# 4  https://a1.muscache.com/ac/users/244186/profil...
#
#   host_total_listings_count                                    host_url  \
# 0                         1  https://www.airbnb.com/users/show/20130073
# 1                         1   https://www.airbnb.com/users/show/8786086
# 2                         1  https://www.airbnb.com/users/show/35283911
# 3                         3  https://www.airbnb.com/users/show/12223017
# 4                         6    https://www.airbnb.com/users/show/244186
#
#                        host_verifications house_rules       id  \
# 0           ['email', 'phone', 'reviews']         NaN  3890624
# 1                      ['email', 'phone']         NaN  1661292
# 2                      ['email', 'phone']         NaN  6737686
# 3  ['email', 'phone', 'reviews', 'jumio']         NaN  5046813
# 4  ['email', 'phone', 'reviews', 'jumio']         NaN   277038
#
#   instant_bookable interaction is_business_travel_ready is_location_exact  \
# 0                f         NaN                      NaN                 t
# 1                f         NaN                      NaN                 t
# 2                f         NaN                      NaN                 t
# 3                f         NaN                      NaN                 f
# 4                t         NaN                      NaN                 t
#
#   jurisdiction_names last_review last_scraped   latitude license  \
# 0                NaN  2014-11-02   2015-07-28  34.132812     NaN
# 1                NaN         NaN   2015-07-28  34.079586     NaN
# 2                NaN         NaN   2015-07-28  34.109388     NaN
# 3                NaN  2015-07-12   2015-07-28  34.029917     NaN
# 4                NaN  2015-06-08   2015-07-28  34.151309     NaN
#
#                             listing_url   longitude       market  \
# 0  https://www.airbnb.com/rooms/3890624 -118.025147  Los Angeles
# 1  https://www.airbnb.com/rooms/1661292 -118.341913  Los Angeles
# 2  https://www.airbnb.com/rooms/6737686 -118.318135  Los Angeles
# 3  https://www.airbnb.com/rooms/5046813 -118.403306  Los Angeles
# 4   https://www.airbnb.com/rooms/277038 -118.106849  Los Angeles
#
#    maximum_nights                                         medium_url  \
# 0          1125.0  https://a0.muscache.com/ac/pictures/52102815/8...
# 1          1125.0  https://a2.muscache.com/ac/pictures/23837943/9...
# 2          1125.0  https://a1.muscache.com/ac/pictures/85102851/4...
# 3          1125.0  https://a0.muscache.com/ac/pictures/74769434/8...
# 4           365.0  https://a2.muscache.com/ac/pictures/7556540/fe...
#
#   minimum_nights monthly_price                                 name  \
# 0              1     $2,500.00  安靜舒適的独立大套房,非常适合专业商務人士，学生，实习，渡假遊學...
# 1              1           NaN  Shared Small Well Decorated & Clean
# 2              1           NaN     "Villa Maria" in Hollywood Hills
# 3              1           NaN                  Extra Large Beanbag
# 4              2     $1,200.00   Great Pasadena Historical Landmark
#
#        neighborhood_overview    neighbourhood neighbourhood_cleansed  \
# 0  风景秀丽，豪宅林立，闹中取静，交通方便，华人超市!              NaN                Arcadia
# 1                        NaN     Mid-Wilshire           Hancock Park
# 2                        NaN  Hollywood Hills        Hollywood Hills
# 3                        NaN              NaN          Cheviot Hills
# 4                        NaN         Pasadena               Pasadena
#
#    neighbourhood_group_cleansed                       notes number_of_reviews  \
# 0                           NaN  无合约要求，适合短期旅游，探亲访友，随时拎包入住，                  2
# 1                           NaN                         NaN                 0
# 2                           NaN                         NaN                 0
# 3                           NaN                         NaN                16
# 4                           NaN                         NaN                28
#
#                                          picture_url      price property_type  \
# 0  https://a0.muscache.com/ac/pictures/52102815/8...     $90.00         House
# 1  https://a2.muscache.com/ac/pictures/23837943/9...     $75.00     Apartment
# 2  https://a1.muscache.com/ac/pictures/85102851/4...  $1,000.00         House
# 3  https://a0.muscache.com/ac/pictures/74769434/8...     $30.00     Apartment
# 4  https://a2.muscache.com/ac/pictures/7556540/fe...     $70.00         House
#
#   require_guest_phone_verification require_guest_profile_picture  \
# 0                                f                             f
# 1                                f                             f
# 2                                f                             f
# 3                                f                             f
# 4                                f                             f
#
#   requires_license  review_scores_accuracy  review_scores_checkin  \
# 0                f                    10.0                   10.0
# 1                f                     NaN                    NaN
# 2                f                     NaN                    NaN
# 3                f                    10.0                   10.0
# 4                f                    10.0                   10.0
#
#    review_scores_cleanliness  review_scores_communication  \
# 0                        8.0                         10.0
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# 3                       10.0                         10.0
# 4                        9.0                         10.0
#
#    review_scores_location  review_scores_rating  review_scores_value  \
# 0                    10.0                  90.0                  8.0
# 1                     NaN                   NaN                  NaN
# 2                     NaN                   NaN                  NaN
# 3                    10.0                  98.0                 10.0
# 4                     9.0                  96.0                 10.0
#
#    reviews_per_month        room_type     scrape_id security_deposit  \
# 0               0.19     Private room  2.015073e+13              NaN
# 1                NaN      Shared room  2.015073e+13              NaN
# 2                NaN  Entire home/apt  2.015073e+13              NaN
# 3               2.46      Shared room  2.015073e+13              NaN
# 4               0.65     Private room  2.015073e+13              NaN
#
#   smart_location                                              space  \
# 0            NaN             安靜舒適的独立大套房. 阳光明媚的大卧室，(附帶冰箱)一个超大衣帽間和浴室.
# 1            NaN                                                NaN
# 2            NaN                                                NaN
# 3            NaN  Check in is 4pm. Check out is 11am. No excepti...
# 4            NaN  If you are planning to visit our wonderful cit...
#
#    square_feet state                                             street  \
# 0          NaN    CA  South 2nd Avenue, Arcadia, CA 91006, United St...
# 1          NaN    CA  North Sycamore Avenue, Los Angeles, CA 90036, ...
# 2          NaN    CA  Foothill Drive, Los Angeles, CA 90068, United ...
# 3          NaN    CA      Club Dr, Los Angeles, CA 90064, United States
# 4        175.0    CA     Martelo Ave, Pasadena, CA 91107, United States
#
#                                              summary  \
# 0  我們j位於Arcadia市中心,非常适合专业商務人士，学生，渡假遊學...鄰近高速公路,餐厅...
# 1  Small but real clean apartment in Hancock Park...
# 2  Originally built in 1922, this Italian-style v...
# 3      Extra comfy beanbag that can easily fit two.
# 4                                                NaN
#
#                                        thumbnail_url  \
# 0  https://a0.muscache.com/ac/pictures/52102815/8...
# 1  https://a2.muscache.com/ac/pictures/23837943/9...
# 2  https://a1.muscache.com/ac/pictures/85102851/4...
# 3  https://a0.muscache.com/ac/pictures/74769434/8...
# 4  https://a2.muscache.com/ac/pictures/7556540/fe...
#
#                                              transit weekly_price  \
# 0  聚集高尔夫球场，网球场，大型购物中心，影院，图书馆，大型街心公园，跑马场，医院，诊所。非常便...      $650.00
# 1                                                NaN      $500.00
# 2                                                NaN    $5,000.00
# 3  #12 Bus is 100 yards from the apartment and ru...          NaN
# 4                                                NaN      $350.00
#
#                                       xl_picture_url zipcode
# 0  https://a0.muscache.com/ac/pictures/52102815/8...   91006
# 1  https://a2.muscache.com/ac/pictures/23837943/9...   90036
# 2  https://a1.muscache.com/ac/pictures/85102851/4...   90068
# 3  https://a0.muscache.com/ac/pictures/74769434/8...   90064
# 4  https://a2.muscache.com/ac/pictures/7556540/fe...   91107

# %% [markdown]
# Checking the number of entries, size, and datatypes of the dataframe:

# %%
listings.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620453 entries, 0 to 620452
# Data columns (total 97 columns):
# access                              322669 non-null object
# accommodates                        620419 non-null object
# amenities                           605932 non-null object
# availability_30                     620439 non-null float64
# availability_365                    620437 non-null object
# availability_60                     620439 non-null object
# availability_90                     620437 non-null float64
# bathrooms                           618643 non-null object
# bed_type                            620453 non-null object
# bedrooms                            619830 non-null object
# beds                                619471 non-null object
# calculated_host_listings_count      620443 non-null object
# calendar_last_scraped               620443 non-null object
# calendar_updated                    620453 non-null object
# cancellation_policy                 605932 non-null object
# city                                620291 non-null object
# cleaning_fee                        490909 non-null object
# country                             620447 non-null object
# country_code                        605914 non-null object
# date_recorded                       620453 non-null object
# description                         616602 non-null object
# experiences_offered                 605930 non-null object
# extra_people                        620451 non-null object
# first_review                        482573 non-null object
# guests_included                     620438 non-null object
# has_availability                    448695 non-null object
# host_about                          411821 non-null object
# host_acceptance_rate                131162 non-null object
# host_has_profile_pic                605606 non-null object
# host_id                             620417 non-null object
# host_identity_verified              605642 non-null object
# host_is_superhost                   620157 non-null object
# host_listings_count                 605642 non-null float64
# host_location                       618143 non-null object
# host_name                           620159 non-null object
# host_neighbourhood                  500994 non-null object
# host_picture_url                    620159 non-null object
# host_response_rate                  493254 non-null object
# host_response_time                  493263 non-null object
# host_since                          620159 non-null object
# host_thumbnail_url                  605606 non-null object
# host_total_listings_count           605629 non-null object
# host_url                            620417 non-null object
# host_verifications                  605900 non-null object
# house_rules                         356861 non-null object
# id                                  620417 non-null object
# instant_bookable                    605898 non-null object
# interaction                         310295 non-null object
# is_business_travel_ready            376317 non-null object
# is_location_exact                   620411 non-null object
# jurisdiction_names                  347133 non-null object
# last_review                         482657 non-null object
# last_scraped                        620411 non-null object
# latitude                            620402 non-null float64
# license                             5434 non-null object
# listing_url                         620402 non-null object
# longitude                           620411 non-null float64
# market                              615193 non-null object
# maximum_nights                      620417 non-null float64
# medium_url                          180571 non-null object
# minimum_nights                      620415 non-null object
# monthly_price                       136649 non-null object
# name                                620305 non-null object
# neighborhood_overview               378577 non-null object
# neighbourhood                       542506 non-null object
# neighbourhood_cleansed              620417 non-null object
# neighbourhood_group_cleansed        0 non-null float64
# notes                               292875 non-null object
# number_of_reviews                   620382 non-null object
# picture_url                         620381 non-null object
# price                               620417 non-null object
# property_type                       620378 non-null object
# require_guest_phone_verification    605864 non-null object
# require_guest_profile_picture       605864 non-null object
# requires_license                    620381 non-null object
# review_scores_accuracy              473264 non-null float64
# review_scores_checkin               472785 non-null float64
# review_scores_cleanliness           473365 non-null float64
# review_scores_communication         473396 non-null float64
# review_scores_location              472762 non-null float64
# review_scores_rating                474123 non-null float64
# review_scores_value                 472640 non-null float64
# reviews_per_month                   482507 non-null float64
# room_type                           620381 non-null object
# scrape_id                           620381 non-null float64
# security_deposit                    395712 non-null object
# smart_location                      590139 non-null object
# space                               454218 non-null object
# square_feet                         8149 non-null float64
# state                               620347 non-null object
# street                              620381 non-null object
# summary                             599208 non-null object
# thumbnail_url                       180537 non-null object
# transit                             363860 non-null object
# weekly_price                        153689 non-null object
# xl_picture_url                      180537 non-null object
# zipcode                             613763 non-null object
# dtypes: float64(17), object(80)
# memory usage: 4.9 GB

# %% [markdown]
# It turns out that a lot of columns can be converted to more accurate, and oftentimes, space-saving datatypes. Additionally, the prices and percentages can be changed into float numbers after removing the '$' and '%' signs from the strings.

# %%
def change_datatypes(df):
    """ Changes the datatypes of specified columns in the dataframe,
        depending on if the dataframe passed to the function has
        listings data or reviews data. Has try/except blocks just in case
        a certain column is not found in a dataframe.
    """
    # lists of columns that need to be converted in listings data
    to_int = ['scrape_id','zipcode','bedrooms','beds','host_listings_count','host_total_listings_count']
    to_datetime = ['last_scraped','host_since','calendar_last_scraped', 'first_review', 'last_review']
    to_bool = ['requires_license','host_is_superhost','host_has_profile_pic','host_identity_verified','is_location_exact','has_availability','instant_bookable','is_business_travel_ready','require_guest_profile_picture','require_guest_phone_verification']
    to_category = ['property_type','room_type','bed_type','cancellation_policy','market','neighbourhood','city','state','calendar_updated','host_neighbourhood']
    prices = ['price','weekly_price','monthly_price','security_deposit','cleaning_fee','extra_people']
    percentages = ['host_response_rate', 'host_acceptance_rate']
    
    ## to integer
    for col_name in to_int:
        try:
            df[col_name] = pd.to_numeric(df[col_name], downcast='integer', errors='coerce')
        except KeyError:
            pass

    ## to datetime: dates are all in YYYY-MM-DD format
    for col_name in to_datetime:
        try:
            df[col_name] = pd.to_datetime(df[col_name], format='%Y-%m-%d')
        except:
            pass

    ## to bool: booleans start out as 't' or 'f' strings
    for col_name in to_bool:
        try:
            df[col_name] = df[col_name] == 't'
        except:
            pass
    
    ## to category
    for col_name in to_category:
        try:
            df[col_name] = df[col_name].astype('category')
        except KeyError:
            pass
       
    ## change price columns
    for col_name in prices:
        try:
            df[col_name] = pd.to_numeric(df[col_name].str.replace('$',''), downcast='float', errors='coerce')
        except:
            pass
        # rename column
        df.rename(columns={col_name: col_name + '_USD'}, inplace=True)

    ## change percentage columns
    for col_name in percentages:
        try:
            df[col_name] = pd.to_numeric(df[col_name].str.replace('%',''), downcast='float', errors='coerce')
        except:
            pass
        # rename column
        df.rename(columns={col_name: col_name + '_percentage'}, inplace=True)
    
    return df

# %%
# change datatypes for listings data
listings = change_datatypes(listings)

# %%
listings.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620453 entries, 0 to 620452
# Data columns (total 97 columns):
# access                              322669 non-null object
# accommodates                        620419 non-null object
# amenities                           605932 non-null object
# availability_30                     620439 non-null float64
# availability_365                    620437 non-null object
# availability_60                     620439 non-null object
# availability_90                     620437 non-null float64
# bathrooms                           618643 non-null object
# bed_type                            620453 non-null category
# bedrooms                            619809 non-null float64
# beds                                619435 non-null float64
# calculated_host_listings_count      620443 non-null object
# calendar_last_scraped               620443 non-null object
# calendar_updated                    620453 non-null category
# cancellation_policy                 605932 non-null category
# city                                620291 non-null category
# cleaning_fee_USD                    490653 non-null float32
# country                             620447 non-null object
# country_code                        605914 non-null object
# date_recorded                       620453 non-null object
# description                         616602 non-null object
# experiences_offered                 605930 non-null object
# extra_people_USD                    620417 non-null float32
# first_review                        482573 non-null object
# guests_included                     620438 non-null object
# has_availability                    620453 non-null bool
# host_about                          411821 non-null object
# host_acceptance_rate_percentage     131132 non-null float32
# host_has_profile_pic                620453 non-null bool
# host_id                             620417 non-null object
# host_identity_verified              620453 non-null bool
# host_is_superhost                   620453 non-null bool
# host_listings_count                 605642 non-null float64
# host_location                       618143 non-null object
# host_name                           620159 non-null object
# host_neighbourhood                  500994 non-null category
# host_picture_url                    620159 non-null object
# host_response_rate_percentage       493226 non-null float32
# host_response_time                  493263 non-null object
# host_since                          620159 non-null object
# host_thumbnail_url                  605606 non-null object
# host_total_listings_count           605606 non-null float64
# host_url                            620417 non-null object
# host_verifications                  605900 non-null object
# house_rules                         356861 non-null object
# id                                  620417 non-null object
# instant_bookable                    620453 non-null bool
# interaction                         310295 non-null object
# is_business_travel_ready            620453 non-null bool
# is_location_exact                   620453 non-null bool
# jurisdiction_names                  347133 non-null object
# last_review                         482657 non-null object
# last_scraped                        620411 non-null object
# latitude                            620402 non-null float64
# license                             5434 non-null object
# listing_url                         620402 non-null object
# longitude                           620411 non-null float64
# market                              615193 non-null category
# maximum_nights                      620417 non-null float64
# medium_url                          180571 non-null object
# minimum_nights                      620415 non-null object
# monthly_price_USD                   8755 non-null float32
# name                                620305 non-null object
# neighborhood_overview               378577 non-null object
# neighbourhood                       542506 non-null category
# neighbourhood_cleansed              620417 non-null object
# neighbourhood_group_cleansed        0 non-null float64
# notes                               292875 non-null object
# number_of_reviews                   620382 non-null object
# picture_url                         620381 non-null object
# price_USD                           608026 non-null float32
# property_type                       620378 non-null category
# require_guest_phone_verification    620453 non-null bool
# require_guest_profile_picture       620453 non-null bool
# requires_license                    620453 non-null bool
# review_scores_accuracy              473264 non-null float64
# review_scores_checkin               472785 non-null float64
# review_scores_cleanliness           473365 non-null float64
# review_scores_communication         473396 non-null float64
# review_scores_location              472762 non-null float64
# review_scores_rating                474123 non-null float64
# review_scores_value                 472640 non-null float64
# reviews_per_month                   482507 non-null float64
# room_type                           620381 non-null category
# scrape_id                           620381 non-null float64
# security_deposit_USD                353023 non-null float32
# smart_location                      590139 non-null object
# space                               454218 non-null object
# square_feet                         8149 non-null float64
# state                               620347 non-null category
# street                              620381 non-null object
# summary                             599208 non-null object
# thumbnail_url                       180537 non-null object
# transit                             363860 non-null object
# weekly_price_USD                    109704 non-null float32
# xl_picture_url                      180537 non-null object
# zipcode                             613528 non-null float64
# dtypes: bool(10), category(10), float32(8), float64(21), object(48)
# memory usage: 3.8 GB

# %% [markdown]
# By changing datatypes, we have already reduced the size of the dataframe by 1.1GB.

# %% [markdown]
# ### Which column to predict?
#
# I'll decide which column to use for predictions - either 'review_scores_rating' or 'price_USD' based on which has the least amount of missing data

# %% [markdown]
# Calculate the amount of missing values for this 'review_scores_rating':

# %%
num_missing = listings.review_scores_rating.isna().sum()
len_col = len(listings.review_scores_rating)
# calculate percentage of missing data
percent_missing = (num_missing/len_col)*100

print('Percentage missing:', percent_missing)
# Out:
# Percentage missing: 23.584381089300884

# %% [markdown]
# Calculate the amount of missing values for 'price_USD' column:

# %%
num_missing = listings.price_USD.isna().sum()
len_col = len(listings.price_USD)
# calculate percentage of missing data
percent_missing = (num_missing/len_col)*100

print('Percentage missing:', percent_missing)
# Out:
# Percentage missing: 2.0028914357735395

# %% [markdown]
# Since only 2% of price data is missing (versus almost 23% for ratings data), it might be a better idea to try to predict the price metric, and to remove rows in the dataframe that do not have price data.

# %% [markdown]
# ### Inspect Price Data

# %% [markdown]
# #### Outliers

# %%
# remove rows without price data
listings = listings[listings.price_USD.notnull()]

# %%
len(listings)
# Out:
# 608026

# %% [markdown]
# Summary statistics for price data:

# %%
listings.price_USD.describe()
# Out:
# count    608026.000000
# mean        151.474228
# std         704.614990
# min           0.000000
# 25%          70.000000
# 50%         100.000000
# 75%         171.000000
# max       90403.000000
# Name: price_USD, dtype: float64

# %% [markdown]
# The summary statistics already tells us that the data has a pretty extreme right skew, since it's mean is 151 and its max is 90,403. Therefore, it will be worth it to inspect the extreme values to see if they are legitimate.
#
# Additionally, the minimum price is 0 , which does not make much sense for an Airbnb listing. We should inspect listings of 0 as well as the extremes on the higher end of the spectrum.

# %%
listings.price_USD.value_counts().sort_index()
# Out:
# 0.0         207
# 2.0           8
# 4.0           1
# 10.0        243
# 11.0          7
# 12.0         49
# 13.0         21
# 14.0         35
# 15.0       1213
# 16.0        282
# 17.0        304
# 18.0        426
# 19.0        373
# 20.0       1555
# 21.0        195
# 22.0        860
# 23.0        520
# 24.0        656
# 25.0       3463
# 26.0        533
# 27.0        729
# 28.0        911
# 29.0       1835
# 30.0       3893
# 31.0        665
# 32.0       1055
# 33.0       1474
# 34.0        766
# 35.0       6049
# 36.0       1101
#            ...
# 950.0       367
# 954.0         2
# 955.0         2
# 956.0         3
# 958.0         2
# 959.0         7
# 960.0        10
# 964.0         1
# 965.0        14
# 969.0        24
# 970.0         5
# 975.0        53
# 976.0         7
# 979.0         2
# 980.0        48
# 985.0        17
# 986.0         8
# 987.0        18
# 988.0         1
# 989.0        10
# 990.0        85
# 995.0       364
# 996.0        15
# 997.0        16
# 998.0        20
# 999.0       460
# 90024.0       9
# 90069.0      11
# 90265.0      14
# 90403.0       2
# Name: price_USD, Length: 836, dtype: int64

# %% [markdown]
# It's surprising that after the top 4 highest prices which are in the 90 thousand dollar range, the next highest price is 999 dollars, two entire orders of magnitude less.
#
# Additionally, there are 207 entries of which the price is 0, and a couple more that have entries under 10 dollars.
#
# These outliers are worth exploring.

# %%
# inspect high outliers
listings[listings.price_USD > 90000]
# Out:
#                                                    access accommodates  \
# 37090                                                 NaN          NaN
# 40143                                                 NaN          NaN
# 41597   I have an interior design business.  I truly l...          NaN
# 50332   I have an interior design business.  I truly l...          NaN
# 71214                                                 NaN          NaN
# 77603                                                 NaN          NaN
# 80861                                                 NaN          NaN
# 82376   I have an interior design business.  I truly l...          NaN
# 91730   I have an interior design business.  I truly l...          NaN
# 139493                                                NaN          NaN
# 142397                                                NaN          NaN
# 143826  I have an interior design business.  I truly l...          NaN
# 152137  I have an interior design business.  I truly l...          NaN
# 198972                                                NaN          NaN
# 201891                                                NaN          NaN
# 211488  I have an interior design business.  I truly l...          NaN
# 219923  I have an interior design business.  I truly l...          NaN
# 240388                                                NaN          NaN
# 243077                                                NaN          NaN
# 377801                                                NaN          NaN
# 380261                                                NaN          NaN
# 422884                                                NaN          NaN
# 425749                                                NaN          NaN
# 434974  I have an interior design business.  I truly l...          NaN
# 442742  I have an interior design business.  I truly l...          NaN
# 511933                                                NaN          50%
# 513119                                                NaN          50%
# 537067  I have an interior design business.  I truly l...          NaN
# 537118  I have an interior design business.  I truly l...          NaN
# 553641                                                NaN          NaN
# 553657                                                NaN          NaN
# 555079                                                NaN          NaN
# 596973                                                NaN          NaN
# 599766                                                NaN          NaN
# 608752  I have an interior design business.  I truly l...          NaN
# 616033  I have an interior design business.  I truly l...          NaN
#
#        amenities  availability_30 availability_365 availability_60  \
# 37090          t       73820979.0                t               t
# 40143          t       20407031.0                f               f
# 41597          t       29814906.0                f               t
# 50332          t       29814906.0                f               t
# 71214          t       20407031.0                f               f
# 77603          t       73820979.0                t               t
# 50332        NaN   NaN                           100%        within an hour
# 71214        NaN   NaN                           100%          within a day
# 77603        NaN   NaN                           100%        within an hour
# 80861        NaN   NaN                           100%          within a day
# 82376        NaN   NaN                           100%        within an hour
# 91730        NaN   NaN                           100%        within an hour
# 139493       NaN   NaN                           100%        within an hour
# 142397       NaN   NaN                            NaN                   NaN
# 143826       NaN   NaN                           100%        within an hour
# 152137       NaN   NaN                           100%        within an hour
# 198972       NaN   NaN                           100%        within an hour
# 201891       NaN   NaN                            NaN                   NaN
# 211488       NaN   NaN                           100%        within an hour
# 219923       NaN   NaN                           100%        within an hour
# 240388       NaN   NaN                            NaN                   NaN
# 243077       NaN   NaN                            NaN                   NaN
# 377801       NaN   NaN                            NaN                   NaN
# 380261       NaN   NaN                            NaN                   NaN
# 422884       NaN   NaN                           100%        within an hour
# 425749       NaN   NaN                            NaN                   NaN
# 434974       NaN   NaN                           100%        within an hour
# 442742       NaN   NaN                           100%        within an hour
# 511933       NaN   NaN                           100%    within a few hours
# 513119       NaN   NaN                           100%    within a few hours
# 537067       NaN   NaN                           100%        within an hour
# 537118       NaN   NaN                           100%        within an hour
# 553641       NaN   NaN                           100%          within a day
# 553657       NaN   NaN                           100%          within a day
# 555079       NaN   NaN                           100%        within an hour
# 596973       NaN   NaN                            NaN                   NaN
# 599766       NaN   NaN                            NaN                   NaN
# 608752       NaN   NaN                           100%        within an hour
# 616033       NaN   NaN                           100%        within an hour
#
#        calendar_updated                                cancellation_policy  \
# 37090        2016-05-24  https://a0.muscache.com/im/pictures/7d7babeb-9...
# 40143        2014-08-22  https://a0.muscache.com/im/pictures/fff25a8b-9...
# 41597        2015-03-22  https://a0.muscache.com/im/pictures/user/9761e...
# 50332        2015-03-22  https://a0.muscache.com/im/pictures/user/9761e...
# 71214        2014-08-22  https://a0.muscache.com/im/pictures/fff25a8b-9...
# 77603        2016-05-24  https://a0.muscache.com/im/pictures/7d7babeb-9...
# 80861        2014-08-22  https://a0.muscache.com/im/pictures/fff25a8b-9...
# 82376        2015-03-22  https://a0.muscache.com/im/pictures/user/9761e...
# 91730        2015-03-22  https://a0.muscache.com/im/pictures/user/9761e...
# 139493       2016-05-24  https://a0.muscache.com/im/pictures/7d7babeb-9...
# 142397       2014-08-22  https://a0.muscache.com/im/pictures/fff25a8b-9...
# 143826       2015-03-22  https://a0.muscache.com/im/pictures/user/9761e...
# 152137       2015-03-22  https://a0.muscache.com/im/pictures/user/9761e...
# 198972       2016-05-24  https://a0.muscache.com/im/pictures/7d7babeb-9...
# 201891       2014-08-22  https://a0.muscache.com/im/pictures/fff25a8b-9...
# 211488       2015-03-22  https://a0.muscache.com/im/pictures/user/9761e...
# 219923       2015-03-22  https://a0.muscache.com/im/pictures/user/9761e...
# 240388       2016-05-24  https://a0.muscache.com/im/pictures/user/37a05...
# 243077       2014-08-22  https://a0.muscache.com/im/pictures/fff25a8b-9...
# 377801       2016-05-24  https://a0.muscache.com/im/pictures/user/37a05...
# 380261       2014-08-22  https://a0.muscache.com/im/pictures/fff25a8b-9...
# 422884       2016-05-24  https://a0.muscache.com/im/pictures/user/37a05...
# 425749       2014-08-22  https://a0.muscache.com/im/pictures/fff25a8b-9...
# 434974       2015-03-22  https://a0.muscache.com/im/pictures/user/9761e...
# 442742       2015-03-22  https://a0.muscache.com/im/pictures/user/9761e...
# 511933       2013-10-02                                                NaN
# 513119       2013-10-02                                                NaN
# 537067       2015-03-22  https://a0.muscache.com/im/pictures/user/9761e...
# 537118       2015-03-22  https://a0.muscache.com/im/pictures/user/9761e...
# 553641       2014-08-22  https://a0.muscache.com/im/pictures/fff25a8b-9...
# 553657       2014-08-22  https://a0.muscache.com/im/pictures/fff25a8b-9...
# 555079       2016-05-24  https://a0.muscache.com/im/pictures/7d7babeb-9...
# 596973       2016-05-24  https://a0.muscache.com/im/pictures/user/37a05...
# 599766       2014-08-22  https://a0.muscache.com/im/pictures/fff25a8b-9...
# 608752       2015-03-22  https://a0.muscache.com/im/pictures/user/9761e...
# 616033       2015-03-22  https://a0.muscache.com/im/pictures/user/9761e...
#
#        city  cleaning_fee_USD  \
# 37090   2.0               NaN
# 40143   1.0               NaN
# 41597   2.0               NaN
# 50332   2.0               NaN
# 71214   2.0               NaN
# 77603   2.0               NaN
# 80861   2.0               NaN
# 82376   2.0               NaN
# 91730   2.0               NaN
# 139493  2.0               NaN
# 142397  1.0               NaN
# 143826  2.0               NaN
# 152137  2.0               NaN
# 198972  1.0               NaN
# 201891  1.0               NaN
# 211488  2.0               NaN
# 219923  2.0               NaN
# 240388  1.0               NaN
# 243077  1.0               NaN
# 377801  1.0               NaN
# 380261  1.0               NaN
# 422884  1.0               NaN
# 425749  1.0               NaN
# 434974  2.0               NaN
# 442742  2.0               NaN
# 511933  NaN               NaN
# 513119  NaN               NaN
# 537067  2.0               NaN
# 537118  2.0               NaN
# 553641  2.0               NaN
# 553657  2.0               NaN
# 555079  1.0               NaN
# 596973  1.0               NaN
# 599766  1.0               NaN
# 608752  2.0               NaN
# 616033  2.0               NaN
#
#                                                   country  \
# 37090   ['email', 'phone', 'facebook', 'reviews', 'kba...
# 40143                         ['email', 'phone', 'jumio']
# 41597   ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 50332   ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 71214                         ['email', 'phone', 'jumio']
# 77603   ['email', 'phone', 'facebook', 'reviews', 'kba...
# 80861                         ['email', 'phone', 'jumio']
# 82376   ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 91730   ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 139493  ['email', 'phone', 'facebook', 'reviews', 'kba...
# 142397                        ['email', 'phone', 'jumio']
# 143826  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 152137  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 198972  ['email', 'phone', 'facebook', 'reviews', 'kba...
# 201891                        ['email', 'phone', 'jumio']
# 211488  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 219923  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 240388  ['email', 'phone', 'facebook', 'reviews', 'kba...
# 243077       ['email', 'phone', 'jumio', 'government_id']
# 377801  ['email', 'phone', 'facebook', 'reviews', 'kba...
# 380261       ['email', 'phone', 'jumio', 'government_id']
# 422884  ['email', 'phone', 'facebook', 'reviews', 'kba...
# 425749       ['email', 'phone', 'jumio', 'government_id']
# 434974  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 442742  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 511933                                                NaN
# 513119                                                NaN
# 537067  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 537118  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 553641                        ['email', 'phone', 'jumio']
# 553657                        ['email', 'phone', 'jumio']
# 555079  ['email', 'phone', 'facebook', 'reviews', 'kba...
# 596973  ['email', 'phone', 'facebook', 'reviews', 'kba...
# 599766       ['email', 'phone', 'jumio', 'government_id']
# 608752  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 616033  ['email', 'phone', 'reviews', 'jumio', 'offlin...
#
#                                              country_code date_recorded  \
# 37090   Smoking is strictly prohibited at all times. S...      18042851
# 40143                                                 NaN      19661400
# 41597                            - Quiet after 10 please.      20296800
# 50332                                                 NaN      23715530
# 71214                                                 NaN      14078781
# 77603   Smoking is strictly prohibited at all times. S...      18042851
# 80861                                                 NaN      19661400
# 82376                            - Quiet after 10 please.      20296800
# 91730                                                 NaN      23715530
# 139493  Smoking is strictly prohibited at all times. S...      18042851
# 139493               NaN            t  {"City of Los Angeles"," CA"}
# 142397               NaN            f                            NaN
# 143826               NaN            t                       {MALIBU}
# 152137               NaN            f                       {MALIBU}
# 198972               NaN            t  {"City of Los Angeles"," CA"}
# 201891               NaN            f                            NaN
# 211488               NaN            f                       {MALIBU}
# 219923               NaN            t                            NaN
# 240388               NaN            t  {"City of Los Angeles"," CA"}
# 243077               NaN            f                            NaN
# 377801               NaN            t  {"City of Los Angeles"," CA"}
# 380261               NaN            f                            NaN
# 422884               NaN            t  {"City of Los Angeles"," CA"}
# 425749               NaN            f                            NaN
# 434974               NaN            f                       {MALIBU}
# 442742               NaN            t                            NaN
# 511933               NaN            t                            NaN
# 513119               NaN            t                            NaN
# 537067               NaN            t                       {MALIBU}
# 537118               NaN            f                       {MALIBU}
# 553641               NaN            f                            NaN
# 553657               NaN            t                            NaN
# 555079               NaN            t  {"City of Los Angeles"," CA"}
# 596973               NaN            t  {"City of Los Angeles"," CA"}
# 599766               NaN            f                            NaN
# 608752               NaN            f                       {MALIBU}
# 616033               NaN            t                       {MALIBU}
#
#         has_availability  host_about  host_acceptance_rate_percentage  \
# 37090              False  2018-06-07                              NaN
# 40143              False  2018-06-06                              NaN
# 41597              False  2018-06-07                              NaN
# 50332              False  2018-06-07                              NaN
# 71214              False  2018-05-11                              NaN
# 77603              False  2018-05-10                              NaN
# 80861              False  2018-05-10                              NaN
# 82376              False  2018-05-10                              NaN
# 91730              False  2018-05-10                              NaN
# 139493             False  2018-07-06                              NaN
# 142397             False  2018-07-06                              NaN
# 143826             False  2018-07-06                              NaN
# 152137             False  2018-07-06                              NaN
# 198972             False  2018-08-07                              NaN
# 201891             False  2018-08-07                              NaN
# 211488             False  2018-08-08                              NaN
# 219923             False  2018-08-08                              NaN
# 240388             False  2018-11-04                              NaN
# 243077             False  2018-11-04                              NaN
# 377801             False  2018-12-07                              NaN
# 380261             False  2018-12-06                              NaN
# 422884             False  2018-09-08                              NaN
# 425749             False  2018-09-08                              NaN
# 434974             False  2018-09-09                              NaN
# 442742             False  2018-09-09                        34.038727
# 511933             False  2015-05-25                        34.023647
# 513119             False  2015-05-25                        34.023766
# 537067             False  2018-04-08                              NaN
# 537118             False  2018-04-07                              NaN
# 553641             False  2018-04-09                        34.089012
# 553657             False  2018-04-09                        34.089035
# 555079             False  2018-04-08                        34.060665
# 596973             False  2018-10-06                              NaN
# 599766             False  2018-10-05                              NaN
# 608752             False  2018-10-06                              NaN
# 616033             False  2018-10-05                              NaN
#
#         host_has_profile_pic                                host_id  \
# 37090                  False  https://www.airbnb.com/rooms/18042851
# 40143                  False  https://www.airbnb.com/rooms/19661400
# 41597                  False  https://www.airbnb.com/rooms/20296800
# 50332                  False  https://www.airbnb.com/rooms/23715530
# 71214                  False  https://www.airbnb.com/rooms/14078781
# 77603                  False  https://www.airbnb.com/rooms/18042851
# 80861                  False  https://www.airbnb.com/rooms/19661400
# 82376                  False  https://www.airbnb.com/rooms/20296800
# 91730                  False  https://www.airbnb.com/rooms/23715530
# 139493                 False  https://www.airbnb.com/rooms/18042851
# 142397                 False  https://www.airbnb.com/rooms/19661400
# 143826                 False  https://www.airbnb.com/rooms/20296800
# 152137                 False  https://www.airbnb.com/rooms/23715530
# 198972                 False  https://www.airbnb.com/rooms/18042851
# 201891                 False  https://www.airbnb.com/rooms/19661400
# 211488                 False  https://www.airbnb.com/rooms/23715530
# 219923                 False  https://www.airbnb.com/rooms/27428144
# 240388                 False  https://www.airbnb.com/rooms/18042851
# 243077                 False  https://www.airbnb.com/rooms/19661400
# 377801                 False  https://www.airbnb.com/rooms/18042851
# 380261                 False  https://www.airbnb.com/rooms/19661400
# 422884                 False  https://www.airbnb.com/rooms/18042851
# 425749                 False  https://www.airbnb.com/rooms/19661400
# 434974                 False  https://www.airbnb.com/rooms/23715530
# 442742                 False  https://www.airbnb.com/rooms/27428144
# 511933                 False   https://www.airbnb.com/rooms/4508710
# 513119                 False   https://www.airbnb.com/rooms/1786766
# 537067                 False  https://www.airbnb.com/rooms/20296800
# 537118                 False  https://www.airbnb.com/rooms/23715530
# 553641                 False  https://www.airbnb.com/rooms/19661400
# 553657                 False  https://www.airbnb.com/rooms/14078781
# 555079                 False  https://www.airbnb.com/rooms/18042851
# 596973                 False  https://www.airbnb.com/rooms/18042851
# 599766                 False  https://www.airbnb.com/rooms/19661400
# 608752                 False  https://www.airbnb.com/rooms/23715530
# 616033                 False  https://www.airbnb.com/rooms/27428144
#
#         host_identity_verified  host_is_superhost  host_listings_count  \
# 37090                    False              False               1125.0
# 40143                    False              False                  7.0
# 41597                    False              False                 60.0
# 50332                    False              False               1125.0
# 71214                    False              False                  5.0
# 77603                    False              False               1125.0
# 80861                    False              False                  7.0
# 82376                    False              False                 60.0
# 91730                    False              False               1125.0
# 139493                   False              False               1125.0
# 142397                   False              False                  7.0
# 143826                   False              False                 60.0
# 152137                   False              False               1125.0
# 198972                   False              False               1125.0
# 201891                   False              False                  7.0
# 211488                   False              False               1125.0
# 219923                   False              False               1125.0
# 240388                   False              False               1125.0
# 243077                   False              False                  7.0
# 377801                   False              False               1125.0
# 380261                   False              False                  7.0
# 422884                   False              False               1125.0
# 425749                   False              False                  7.0
# 434974                   False              False               1125.0
# 442742                   False              False               1125.0
# 511933                   False              False               1125.0
# 513119                   False              False               1125.0
# 537067                   False              False                 60.0
# 537118                   False              False               1125.0
# 553641                   False              False                  7.0
# 553657                   False              False                  5.0
# 555079                   False              False               1125.0
# 596973                   False              False               1125.0
# 599766                   False              False                  7.0
# 608752                   False              False               1125.0
# 616033                   False              False               1125.0
#
#        host_location host_name host_neighbourhood  \
# 37090            NaN         1                NaN
# 40143            NaN         3                NaN
# 41597            NaN         2                NaN
# 50332            NaN         2                NaN
# 71214            NaN         3                NaN
# 77603            NaN         1                NaN
# 80861            NaN         3                NaN
# 82376            NaN         2                NaN
# 91730            NaN         2                NaN
# 139493           NaN         1                NaN
# 142397           NaN         3                NaN
# 143826           NaN         2                NaN
# 152137           NaN         2                NaN
# 198972           NaN         1                NaN
# 201891           NaN         3                NaN
NaN   NaN          NaN   NaN    NaN     NaN           NaN
# 608752            NaN   NaN          NaN   NaN    NaN     NaN           NaN
# 616033            NaN   NaN          NaN   NaN    NaN     NaN           NaN
#
#        transit  weekly_price_USD xl_picture_url  zipcode
# 37090      NaN               NaN            NaN      NaN
# 40143      NaN               NaN            NaN      NaN
# 41597      NaN               NaN            NaN      NaN
# 50332      NaN               NaN            NaN      NaN
# 71214      NaN               NaN            NaN      NaN
# 77603      NaN               NaN            NaN      NaN
# 80861      NaN               NaN            NaN      NaN
# 82376      NaN               NaN            NaN      NaN
# 91730      NaN               NaN            NaN      NaN
# 139493     NaN               NaN            NaN      NaN
# 142397     NaN               NaN            NaN      NaN
# 143826     NaN               NaN            NaN      NaN
# 152137     NaN               NaN            NaN      NaN
# 198972     NaN               NaN            NaN      NaN
# 201891     NaN               NaN            NaN      NaN
# 211488     NaN               NaN            NaN      NaN
# 219923     NaN               NaN            NaN      NaN
# 240388     NaN               NaN            NaN      NaN
# 243077     NaN               NaN            NaN      NaN
# 377801     NaN               NaN            NaN      NaN
# 380261     NaN               NaN            NaN      NaN
# 422884     NaN               NaN            NaN      NaN
# 425749     NaN               NaN            NaN      NaN
# 434974     NaN               NaN            NaN      NaN
# 442742     NaN               NaN            NaN      NaN
# 511933     NaN               NaN            NaN      NaN
# 513119     NaN               NaN            NaN      NaN
# 537067     NaN               NaN            NaN      NaN
# 537118     NaN               NaN            NaN      NaN
# 553641     NaN               NaN            NaN      NaN
# 553657     NaN               NaN            NaN      NaN
# 555079     NaN               NaN            NaN      NaN
# 596973     NaN               NaN            NaN      NaN
# 599766     NaN               NaN            NaN      NaN
# 608752     NaN               NaN            NaN      NaN
# 616033     NaN               NaN            NaN      NaN

# %%
listings.bathrooms.value_counts()
# Out:
# 1.0                                         297767
# 1.0                                         133545
# 2.0                                          61549
# 2.0                                          30443
# 1.5                                          21699
# 3.0                                          11826
# 2.5                                          11378
# 1.5                                           8484
# 3.0                                           6084
# 2.5                                           5272
# 3.5                                           3368
# 4.0                                           2310
# 0.5                                           1944
# 3.5                                           1733
# 0.0                                           1650
# 4.0                                           1366
# 4.5                                           1019
# 5.0                                            664
# 0.5                                            642
# 4.5                                            609
# 8.0                                            498
# 0.0                                            481
# 5.0                                            472
# 5.5                                            275
# 6.0                                            211
# 5.5                                            190
# 11.0                                           132
# 7.0                                            123
# 6.0                                            110
# 8.0                                            109
# 6.5                                             65
# 6.5                                             58
# 7.5                                             31
# 11.0                                            20
# 7.0                                             19
# 7.5                                             16
# Malibu, California, United States               14
# Beverly Hills, California, United States        11
# 9.5                                             11
# Los Angeles, California, United States           9
# 11.5                                             6
# 9.5                                              4
# 9.0                                              3
# 10.0                                             2
# Santa Monica, California, United States          2
# 19.0                                             2
# 12.0                                             1
# 10.0                                             1
# 68.5                                             1
# 19.0                                             1
# 8.5                                              1
# 13.5                                             1
# 9.0                                              1
# Name: bathrooms, dtype: int64

# %%
listings[listings.price_USD > 90000].bathrooms.value_counts()
# Out:
# Malibu, California, United States           14
# Beverly Hills, California, United States    11
# Los Angeles, California, United States       9
# Santa Monica, California, United States      2
# Name: bathrooms, dtype: int64

# %% [markdown]
# From looking up the listing's webpages, it appears that the outliers represent real listings that appear as outliers in the dataframe due to incorrect data entry, which has led to the nonsensical values seen in the columns above. Since they only account for about 36 entries, I think its worth it to get rid of them:

# 602963    https://www.airbnb.com/rooms/21187671
# Name: listing_url, Length: 207, dtype: object

# %%
# percentage of listings where the price is $0
(len(listings[listings.price_USD == 0]) / len(listings))*100
# Out:
# 0.03404661260876001

# %% [markdown]
# From inspecting the URLs, it looks like some of these listings no longer exist, while others are legitimate and must have been victim to data entry error. Since these listings account for 0.3% of the total dataframe, I think its ok to remove them from the dataset:

# %%
# remove outliers where price is $0
listings = listings[listings.price_USD != 0]

# %%
len(listings)
# Out:
# 607783

# %% [markdown]
# #### Histograms and Boxplots

# %%
listings['price_USD'].plot(kind='hist')
plt.xlabel('Listing price (USD)')
plt.title('Distribution of listing prices in Los Angeles')
# Out:
# Text(0.5,1,'Distribution of listing prices in Los Angeles')

# %%
listings.boxplot(column='price_USD')
plt.xlabel('Listing price (USD)')
plt.title('Distribution of listing prices in Los Angeles')
# Out:
# Text(0.5,1,'Distribution of listing prices in Los Angeles')

# %% [markdown]
# From the histogram and boxplot, it's obvious that the data is very skewed, but from our analysis we know that the outliers are likely real listings, but are just more rare for a service like Airbnb where most customers are looking for affordable prices.

# %% [markdown]
# ### Tidying Data:

# %% [markdown]
# #### Zipcodes
# I referenced http://file.lacounty.gov/SDSInter/lac/1031552_MasterZipCodes.pdf for zipcodes in Los Angeles. It's important to see if the data is what we expect it to be:

# %%
# remove change zipcodes not in range to N/A
la_zip = listings[(listings.zipcode > 90000) & (listings.zipcode < 93591)]
print('Listings length:', len(listings))
print('LA_zip length:', len(la_zip))
print('Percent data lost:', (len(listings)-len(la_zip))/len(listings))
# Out:
# Listings length: 607783
# LA_zip length: 601000
# Percent data lost: 0.011160233175327378

# %% [markdown]
# Since getting rid of non-LA zipcodes only reduces the dataset by 1%, I'll remove this data from the dataset:

# %%
# remove all non-LA zipcodes to null values
listings = listings[(listings.zipcode > 90000) & (listings.zipcode < 93591)]

# %%
len(listings)
# Out:
# 601000

# %% [markdown]
# #### Property Type

# %%
listings['property_type'].value_counts(dropna=False).sort_index()
# Out:
# NaN                            3
# Aparthotel                   259
# Apartment                 257025
# Barn                          32
# Bed & Breakfast             3220
# Bed and breakfast           1883
# Boat                         572
# Boutique hotel              1055
# Bungalow                   12952
# Bus                           16
# Cabin                       1589
# Camper/RV                   2269
# Campsite                      35
# Casa particular                1
# Casa particular (Cuba)         9
# Castle                       195
# Cave                           6
# Chalet                       152
# Condominium                22597
# Cottage                     1265
# Dome house                    25
# Dorm                         924
# Earth House                   23
# Earth house                   77
# Entire Floor                   9
# Farm stay                    253
# Guest suite                10262
# Guesthouse                 18619
# Hostel                      3138
# Hotel                        284
# House                     218175
# Houseboat                     23
# Hut                           86
# In-law                        38
# Island                        15
# Lighthouse                    22
# Loft                       12866
# Minsu (Taiwan)                 5
# Nature lodge                   6
# Other                       4414
# Parking Space                 12
# Plane                         16
# Resort                        14
# Serviced apartment          3212
# Tent                         383
# Timeshare                      1
# Tiny house                   333
# Tipi                          71
# Townhouse                  16076
# Train                         19
# Treehouse                    207
# Vacation home                 70
# Villa                       5981
# Yurt                         206
# Name: property_type, dtype: int64

# %% [markdown]
# There are slight differences in spelling and capitalization for these categories that should be fixed:

# %%
# fix slight differences in spelling and capitalization
listings['property_type'] = listings['property_type'].str.replace('Bed & breakfast', 'Bed and Breakfast')\
                                                    .str.replace('Casa particular (Cuba)', 'Casa particular')\
                                                    .str.replace('Earth house', 'Earth House')

# %% [markdown]
# #### Room Type

# %%
listings['room_type'].value_counts(dropna=False).sort_index()
# Out:
# Entire home/apt    357834
# Private room       215651
# Shared room         27515
# Name: room_type, dtype: int64

# %% [markdown]
# There are no slight errors, so we don't need to change the room type column.

# %% [markdown]
# #### Bed Type

# %%
listings['bed_type'].value_counts(dropna=False).sort_index()
# Out:
# Airbed             3154
# Arya                  0
# Couch              2252
# Eliza                 0
# Futon              5368
# Jay                   0
# Newsha                0
# Pull-out Sofa      3620
# Real Bed         586606
# Name: bed_type, dtype: int64

# %% [markdown]
# It looks like there may be some errors in the bed type column where people's names are listed instead of beds, but there are no listings counted for these data points. Therefore, I will not change the column.

# %% [markdown]
# #### Cancellation Policy

# %%
listings['cancellation_policy'].value_counts(dropna=False).sort_index()
# Out:
# NaN                                                                                                            14230
# flexible                                                                                                      178855
# https://a0.muscache.com/im/pictures/7d7babeb-98f9-4bb1-a57d-88f10ed22d73.jpg?aki_policy=profile_small              0
# https://a0.muscache.com/im/pictures/fff25a8b-9688-4e4b-8559-6d11651fb618.jpg?aki_policy=profile_small              0
# https://a0.muscache.com/im/pictures/user/37a056bf-5a0d-4c07-8d4f-73b3f7aa5bee.jpg?aki_policy=profile_small         0
# https://a0.muscache.com/im/pictures/user/9761e0d9-ba9c-4d69-b119-95274f520a6d.jpg?aki_policy=profile_small         0
# moderate                                                                                                      159167
# no_refunds                                                                                                         7
# strict                                                                                                        110847
# strict_14_with_grace_period                                                                                   136270
# super_strict_30                                                                                                   74
# super_strict_60                                                                                                 1550
# Name: cancellation_policy, dtype: int64

# %% [markdown]
# Like the previous column, it looks like there may be some errors where picture URLs are listed instead of cancellation policies, but there are no listings counted for these data points. Therefore, I will not change the column.

# %% [markdown]
# #### City

# %%
listings['city'].value_counts(dropna=False).sort_index()
# Out:
# NaN                                                89
# \nBrentwood los angeles                             2
#  Hollywood                                          2
#  Hollywood/Highland                                 5
#  Los Angeles                                       45
#  North Hollywood                                    6
#  Porter Ranch                                       3
#  Venice                                            12
#  Venice Los Angeles                                20
# 1.0                                                 0
# 2.0                                                 0
# 600 Atlantic Blvd #309 Monterey Park CA 91754       3
# Acton                                              61
# Agoura Hills                                      869
# Agoura Hills-Malibu                                36
# Agoura hills                                       12
# Agua Dulce                                        103
# Alhambra                                         3075
# Alhambra                                            2
# Altadena                                         2891
# Arcadia                                          3617
# Arcadia                                            13
# Arcadia, California, US                             4
# Arleta                                              7
# Artesia                                            82
# Avalon                                           1619
# Azusa                                             815
# Baldwin Park                                      225
# Beach City                                          2
# Bel Air                                            26
#                                                  ...
# לוס אנג'לס                                          1
# ガーデナ (カリフォルニア州)                                     2
# 亚凯迪亚                                                4
# 南艾尔蒙地                                               3
# 哈仙达岗                                               56
# 因達斯特里                                               2
# 圣加百利                                               19
# 圣马力诺                                                3
# 天普市                                                 9
# 戴蒙德巴                                                2
# 拉蓬特                                                20
# 沃尔纳特                                               16
# 波摩纳                                                 4
# 洛杉矶                                                41
# 洛杉磯                                                 2
# 罗兰岗                                                14
# 罗兰高地                                               70
# 艾尔蒙地                                               14
# 蒙特克莱                                                1
# 蒙特利帕克                                              11
# 西科维纳                                                3
# 钻石吧                                                 4
# 阿卡迪亚                                               22
# 阿罕布拉                                                2
# 阿苏萨                                                 3
# 霍桑                                                  1
# 霍索恩                                                 1
# 马里布                                                 0
# 로스앤젤레스                                              1
# ｐａｃｉｆｉｃ　ｐａｌｉｓａｄｅｓ                                   1
# Name: city, Length: 676, dtype: int64

# %%
# fix slight differences in spelling and capitalization
listings['city'] = listings['city'].str.replace('Arcadia ', 'Arcadia')\
                                                    .str.replace('Arcadia, California, US', 'Arcadia')\
                                                    .str.replace('Agoura Hills-Malibu', 'Agoura Hills')\
                                                    .str.replace('Agoura hills','Agoura Hills')\
                                                    .str.replace('Alhambra ', 'Alhambra')

# %% [markdown]
# #### State

# %%
listings['state'].value_counts(dropna=False).sort_index()
# Out:
# NaN                 3
# AZ                  0
# BAJA .  Ca          0
# CA             600744
# Ca                125
# DC                  8
# GA                  4
# HI                  0
# IA                  2
# ID                  0
# IL                  0
# LA                  0
# MA                  0
# MB                  0
# Malopolskie         0
# NV                  0
# NY                  1
# TN                  0
# TX                 10
# Tuscany             0
# Valenciana          0
# ca                 92
# 加州                  5
# 加洲                  6
# Name: state, dtype: int64

# %%
# fix slight differences in spelling and capitalization
listings['state'] = listings['state'].str.replace('Ca', 'CA')\
                                                    .str.replace('BAJA .  Ca', 'CA')\
                                                    .str.replace('ca', 'CA')
listings = listings[listings['state'] == 'CA']

# %%
len(listings)
# Out:
# 600961

# %% [markdown]
# #### Amenities
# Process 'amenities' columns, which is presently a string containing a list of amenities at that listing. I want to turn each amenity into a separate column of boolean type.

# %%
#remove extra characters
listings['amenities'] = listings.amenities.str.replace('{','').str.replace('}','').str.replace('"','')

# %%
listings.amenities.value_counts(dropna=False).sort_index()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                   5996
# Air Conditioning                                                                                                                                                                                                                                                                                                                                                     1
# Air Conditioning,Elevator in Building,Buzzer/Wireless Intercom,Washer,Dryer,Smoke Detector,Carbon Monoxide Detector,First Aid Kit,Safety Card                                                                                                                                                                                                                        1
# Air Conditioning,Elevator in Building,Heating,Family/Kid Friendly,Washer,Dryer,Smoke Detector,Essentials,Hair Dryer,Iron,Laptop Friendly Workspace                                                                                                                                                                                                                   2
# Air Conditioning,Free Parking on Premises                                                                                                                                                                                                                                                                                                                            1
# Air Conditioning,Free Parking on Premises,Breakfast,Indoor Fireplace,Heating,Family/Kid Friendly,Smoke Detector,Carbon Monoxide Detector,First Aid Kit,Fire Extinguisher,Shampoo,Lock on Bedroom Door,24-Hour Check-in,Hair Dryer                                                                                                                                    2
ation missing: en.hosting_amenity_49,translation missing: en.hosting_amenity_50                                                                                                                            1
# Air Conditioning,Hot Tub,Washer,Dryer,Essentials,Shampoo                                                                                                                                                                                                                                                                                                             2
# Air Conditioning,Indoor Fireplace,Buzzer/Wireless Intercom,Heating,Smoke Detector,Carbon Monoxide Detector,First Aid Kit,Safety Card,Fire Extinguisher,Essentials                                                                                                                                                                                                    1
#                                                                                                                                                                                                                                                                                                                                                                  ...
# Wireless Internet,Wheelchair accessible,Kitchen,Dryer,Iron,translation missing: en.hosting_amenity_49,translation missing: en.hosting_amenity_50                                                                                                                                                                                                                     3
# Wireless Internet,Wheelchair accessible,Kitchen,Free parking on premises,Pets allowed,Breakfast,Pets live on this property,Dog(s),Heating,Family/kid friendly,Washer,Fire extinguisher,Essentials,Shampoo,24-hour check-in,Hangers,Hair dryer,Laptop friendly workspace,Private entrance                                                                             3
# Wireless Internet,Wheelchair accessible,Kitchen,Free parking on premises,Pets allowed,Pets live on this property,Dog(s),Cat(s),Family/kid friendly,Washer,Dryer,Essentials,Laptop friendly workspace,translation missing: en.hosting_amenity_50                                                                                                                      3
# Wireless Internet,Wheelchair accessible,Kitchen,Free parking on premises,Pets live on this property,Family/kid friendly,Fire extinguisher,Essentials,Shampoo,translation missing: en.hosting_amenity_50                                                                                                                                                              1
# Wireless Internet,Wheelchair accessible,Kitchen,Free parking on premises,Smoking allowed,Family/kid friendly,Smoke detector,Carbon monoxide detector,Essentials,Hangers,Iron                                                                                                                                                                                         2
# Wireless Internet,Wheelchair accessible,Kitchen,Free parking on premises,Smoking allowed,Gym,Elevator in building,Indoor fireplace,Washer,Dryer,Smoke detector,Essentials,Hangers,Hair dryer,Iron,Laptop friendly workspace                                                                                                                                          3
# Wireless Internet,Wheelchair accessible,Kitchen,Free parking on premises,Smoking allowed,Pets allowed,Hot tub,Heating,Family/kid friendly,Suitable for events,Washer,Dryer,Essentials,24-hour check-in,Hangers                                                                                                                                                       3
# Wireless Internet,Wheelchair accessible,Kitchen,Free parking on premises,Smoking allowed,Pets allowed,Pets live on this property,Dog(s),Heating,Family/kid friendly,Washer,Fire extinguisher,Essentials,Shampoo,24-hour check-in,Hangers,Hair dryer,Laptop friendly workspace,Private entrance                                                                       3
# Wireless Internet,Wheelchair accessible,Kitchen,Heating,Washer,Dryer,Smoke detector,Carbon monoxide detector,First aid kit,Safety card,Essentials,Shampoo,Lock on bedroom door,Hangers,Hair dryer,Iron,Laptop friendly workspace,translation missing: en.hosting_amenity_49,translation missing: en.hosting_amenity_50                                               3
# Wireless Internet,Wheelchair accessible,Pool,Free parking on premises,Pets live on this property,Dog(s),Heating,Family/kid friendly,Smoke detector,Safety card,Essentials,Shampoo                                                                                                                                                                                    3
# Wireless Internet,Wheelchair accessible,Pool,Heating,translation missing: en.hosting_amenity_49,translation missing: en.hosting_amenity_50                                                                                                                                                                                                                           3
# Wireless Internet,Wheelchair accessible,Pool,Kitchen,Pets allowed,Pets live on this property,Dog(s),Elevator in building,Hot tub,Indoor fireplace,Washer,Dryer,Smoke detector,Carbon monoxide detector,Fire extinguisher,Essentials,Shampoo,24-hour check-in,Hair dryer,translation missing: en.hosting_amenity_49,translation missing: en.hosting_amenity_50        3
# Wireless Internet,Wheelchair accessible,Pool,Smoking allowed,Pets allowed,Pets live on this property,Hot tub,Heating,Family/kid friendly,Suitable for events,Washer,Dryer,Smoke detector,First aid kit,Fire extinguisher,Essentials,Shampoo                                                                                                                          2
# Wireless Internet,Wheelchair accessible,Pool,Smoking allowed,Pets allowed,Pets live on this property,Hot tub,Heating,Family/kid friendly,Suitable for events,Washer,Dryer,Smoke detector,First aid kit,Fire extinguisher,Essentials,Shampoo,Hangers,Hair dryer                                                                                                       1
# Wireless Internet,Wheelchair accessible,Smoking allowed,Family/kid friendly,Smoke detector,Carbon monoxide detector,First aid kit,Essentials,Shampoo,Lock on bedroom door,Hangers,Hair dryer,Laptop friendly workspace,translation missing: en.hosting_amenity_50                                                                                                    2
# Wireless Internet,translation missing: en.hosting_amenity_49                                                                                                                                                                                                                                                                                                         5
# Wireless Internet,translation missing: en.hosting_amenity_49,translation missing: en.hosting_amenity_50                                                                                                                                                                                                                                                             18
# translation missing: en.hosting_amenity_49                                                                                                                                                                                                                                                                                                                          49
# translation missing: en.hosting_amenity_49,translation missing: en.hosting_amenity_50                                                                                                                                                                                                                                                                              534
# translation missing: en.hosting_amenity_49,translation missing: en.hosting_amenity_50,Host greets you                                                                                                                                                                                                                                                               11
# translation missing: en.hosting_amenity_49,translation missing: en.hosting_amenity_50,Self Check-In,Keypad                                                                                                                                                                                                                                                           5
# translation missing: en.hosting_amenity_49,translation missing: en.hosting_amenity_50,Self Check-In,Lockbox                                                                                                                                                                                                                                                          3
# translation missing: en.hosting_amenity_49,translation missing: en.hosting_amenity_50,Self Check-In,Smartlock                                                                                                                                                                                                                                                        2
# translation missing: en.hosting_amenity_49,translation missing: en.hosting_amenity_50,Self check-in,Building staff                                                                                                                                                                                                                                                   8
# translation missing: en.hosting_amenity_49,translation missing: en.hosting_amenity_50,Self check-in,Front desk/doorperson                                                                                                                                                                                                                                            1
# translation missing: en.hosting_amenity_49,translation missing: en.hosting_amenity_50,Self check-in,Keypad                                                                                                                                                                                                                                                          10
# translation missing: en.hosting_amenity_49,translation missing: en.hosting_amenity_50,Self check-in,Lockbox                                                                                                                                                                                                                                                          9
# translation missing: en.hosting_amenity_49,translation missing: en.hosting_amenity_50,Self check-in,Smart lock                                                                                                                                                                                                                                                       5
# translation missing: en.hosting_amenity_50                                                                                                                                                                                                                                                                                                                          13
# NaN                                                                                                                                                                                                                                                                                                                                                              14230
# Name: amenities, Length: 172442, dtype: int64

# %%
# create a set of unique amenities from the Series
unique_amenities = set()

for entry in listings.amenities:
    try:
        amenity_list = entry.split(',')
        for amenity in amenity_list:
            unique_amenities.add(amenity)
    except AttributeError:
        pass

unique_amenities = list(unique_amenities)
unique_amenities.sort()
print(unique_amenities)
# Out:
# ['', ' toilet', '24-Hour Check-in', '24-hour check-in', 'Accessible-height bed', 'Accessible-height toilet', 'Air Conditioning', 'Air conditioning', 'Air purifier', 'Alfresco bathtub', 'Amazon Echo', 'BBQ grill', 'Baby bath', 'Baby monitor', 'Babysitter recommendations', 'Balcony', 'Bath towel', 'Bathroom essentials', 'Bathtub', 'Bathtub with bath chair', 'Beach essentials', 'Beach view', 'Beachfront', 'Bed linens', 'Bedroom comforts', 'Bidet', 'Body soap', 'Breakfast', 'Breakfast table', 'Brick oven', 'Building staff', 'Buzzer/Wireless Intercom', 'Buzzer/wireless intercom', 'Cable TV', 'Carbon Monoxide Detector', 'Carbon monoxide detector', 'Cat(s)', 'Ceiling fan', 'Ceiling hoist', 'Central air conditioning', 'Changing table', 'Children’s books and toys', 'Children’s dinnerware', 'Cleaning before checkout', 'Coffee maker', 'Convection oven', 'Cooking basics', 'Crib', 'DVD player', 'Day bed', 'Disabled parking spot', 'Dishes and silverware', 'Dishwasher', 'Dog(s)', 'Doorman', 'Doorman Entry', 'Double oven', 'Dryer', 'EV charger', 'Electric profiling bed', 'Elevator', 'Elevator in Building', 'Elevator in building', 'En suite bathroom', 'Espresso machine', 'Essentials', 'Ethernet connection', 'Exercise equipment', 'Extra pillows and blankets', 'Family/Kid Friendly', 'Family/kid friendly', 'Fax machine', 'Fire Extinguisher', 'Fire extinguisher', 'Fire pit', 'Fireplace guards', 'Firm mattress', 'First Aid Kit', 'First aid kit', 'Fixed grab bars for shower', 'Fixed grab bars for toilet', 'Flat path to front door', 'Formal dining area', 'Free Parking on Premises', 'Free parking on premises', 'Free parking on street', 'Free street parking', 'Front desk/doorperson', 'Full kitchen', 'Game console', 'Garden or backyard', 'Gas oven', 'Ground floor access', 'Gym', 'HBO GO', 'Hair Dryer', 'Hair dryer', 'Hammock', 'Handheld shower head', 'Hangers', 'Heat lamps', 'Heated floors', 'Heated towel rack', 'Heating', 'High chair', 'High-resolution computer monitor', 'Host greets you', 'Hot Tub', 'Hot tub', 'Hot water', 'Hot water kettle', 'Indoor Fireplace', 'Indoor fireplace', 'Internet', 'Iron', 'Jetted tub', 'Keypad', 'Kitchen', 'Kitchenette', 'Lake access', 'Laptop Friendly Workspace', 'Laptop friendly workspace', 'Lock on Bedroom Door', 'Lock on bedroom door', 'Lockbox', 'Long term stays allowed', 'Luggage dropoff allowed', 'Memory foam mattress', 'Microwave', 'Mini fridge', 'Misting system', 'Mobile hoist', 'Mountain view', 'Mudroom', 'Murphy bed', 'Netflix', 'Other', 'Other pet(s)', 'Outdoor kitchen', 'Outdoor parking', 'Outdoor seating', 'Outlet covers', 'Oven', 'Pack ’n Play/travel crib', 'Paid parking off premises', 'Paid parking on premises', 'Patio or balcony', 'Pets Allowed', 'Pets allowed', 'Pets live on this property', 'Pillow-top mattress', 'Pocket wifi', 'Pool', 'Pool cover', 'Pool toys', 'Pool with pool hoist', 'Printer', 'Private bathroom', 'Private entrance', 'Private gym', 'Private hot tub', 'Private living room', 'Private pool', 'Projector and screen', 'Rain shower', 'Refrigerator', 'Roll-in shower', 'Roll-in shower with chair', 'Room-darkening shades', 'Safety Card', 'Safety card', 'Sauna', 'Self Check-In', 'Self check-in', 'Shampoo', 'Shared gym', 'Shared hot tub', 'Shared pool', 'Shower chair', 'Single level home', 'Ski in/Ski out', 'Ski-in/Ski-out', 'Smart TV', 'Smart lock', 'Smartlock', 'Smoke Detector', 'Smoke detector', 'Smoking Allowed', 'Smoking allowed', 'Soaking tub', 'Sound system', 'Stair gates', 'Stand alone steam shower', 'Standing valet', 'Steam oven', 'Step-free access', 'Stove', 'Suitable for Events', 'Suitable for events', 'Sun loungers', 'TV', 'Table corner guards', 'Tennis court', 'Terrace', 'Toilet paper', 'Touchless faucets', 'Walk-in shower', 'Warming drawer', 'Washer', 'Washer / Dryer', 'Waterfront', 'Well-lit path to entrance', 'Wheelchair Accessible', 'Wheelchair accessible', 'Wide clearance to bed', 'Wide clearance to shower', 'Wide doorway', 'Wide entryway', 'Wide hallway clearance', 'Wifi', 'Wind ...

# %%
listings['amenities'] = listings['amenities'].str.replace('24-hour check-in', '24-Hour Check-in')\
                                                    .str.replace('Air conditioning', 'Air Conditioning')\
                                                    .str.replace('Buzzer/wireless intercom', 'Buzzer/Wireless Intercom')\
                                                    .str.replace('Carbon monoxide detector', 'Cardon Monoxide Detector')\
                                                    .str.replace('Doorman Entry', 'Doorman')\
                                                    .str.replace('Elevator in Building', 'Elevator')\
                                                    .str.replace('Elevator in building', 'Elevator')\
                                                    .str.replace('Family/kid friendly', 'Family/Kid Friendly')\
                                                    .str.replace('Fire extinguisher', 'Fire Extinguisher')\
                                                    .str.replace('First aid kit', 'First Aid Kit')\
                                                    .str.replace('Free parking on premises', 'Free Parking on Premises')\
                                                    .str.replace('Hair dryer', 'Hair Dryer')\
                                                    .str.replace('Hot tub', 'Hot Tub')\
                                                    .str.replace('Indoor fireplace', 'Indoor Fireplace')\
                                                    .str.replace('Laptop friendly workspace', 'Laptop Friendly Workspace')\
                                                    .str.replace('Lock on bedroom door', 'Lock on Bedroom Door')\
                                                    .str.replace('Pets allowed', 'Pets Allowed')\
                                                    .str.replace('Safety card', 'Safety Card')\
                                                    .str.replace('Self check-in', 'Self Check-In')\
                                                    .str.replace('Ski in/Ski out', 'Ski-in/Ski-out')\
                                                    .str.replace('Smartlock', 'Smart lock')\
                                                    .str.replace('Smoke detector', 'Smoke Detector')\
                                                    .str.replace('Smoking allowed', 'Smoking Allowed')\
                                                    .str.replace('Suitable for events', 'Suitable for Events')\
                                                    .str.replace('Wheelchair accessible', 'Wheelchair Accessible')\
                                                    .str.replace('translation missing: en.hosting_amenity_49', '')\
                                                    .str.replace('translation missing: en.hosting_amenity_50', '')
listings['amenities'] = listings['amenities'].str.split(',')

# %%
# create new list of unique amenities from the redone Series
all_amenities = []

for entry in listings.amenities:
    try:
        all_amenities.extend(entry)
    except TypeError: # if nan value
        pass

unique_amenities = list(set(all_amenities))
unique_amenities.sort()
unique_amenities
# Out:
# ['',
#  ' toilet',
#  '24-Hour Check-in',
#  'Accessible-height bed',
#  'Accessible-height toilet',
#  'Air Conditioning',
#  'Air purifier',
#  'Alfresco bathtub',
#  'Amazon Echo',
#  'BBQ grill',
#  'Baby bath',
#  'Baby monitor',
#  'Babysitter recommendations',
#  'Balcony',
#  'Bath towel',
#  'Bathroom essentials',
#  'Bathtub',
#  'Bathtub with bath chair',
#  'Beach essentials',
#  'Beach view',
#  'Beachfront',
#  'Bed linens',
#  'Bedroom comforts',
#  'Bidet',
#  'Body soap',
#  'Breakfast',
#  'Breakfast table',
#  'Brick oven',
#  'Building staff',
#  'Buzzer/Wireless Intercom',
#  'Cable TV',
#  'Carbon Monoxide Detector',
#  'Cardon Monoxide Detector',
#  'Cat(s)',
#  'Ceiling fan',
#  'Ceiling hoist',
#  'Central air conditioning',
#  'Changing table',
#  'Children’s books and toys',
#  'Children’s dinnerware',
#  'Cleaning before checkout',
#  'Coffee maker',
#  'Convection oven',
#  'Cooking basics',
#  'Crib',
#  'DVD player',
#  'Day bed',
#  'Disabled parking spot',
#  'Dishes and silverware',
#  'Dishwasher',
#  'Dog(s)',
#  'Doorman',
#  'Double oven',
#  'Dryer',
#  'EV charger',
#  'Electric profiling bed',
#  'Elevator',
#  'En suite bathroom',
#  'Espresso machine',
#  'Essentials',
#  'Ethernet connection',
#  'Exercise equipment',
#  'Extra pillows and blankets',
#  'Family/Kid Friendly',
#  'Fax machine',
#  'Fire Extinguisher',
#  'Fire pit',
#  'Fireplace guards',
#  'Firm mattress',
#  'First Aid Kit',
#  'Fixed grab bars for shower',
#  'Fixed grab bars for toilet',
#  'Flat path to front door',
#  'Formal dining area',
#  'Free Parking on Premises',
#  'Free parking on street',
#  'Free street parking',
#  'Front desk/doorperson',
#  'Full kitchen',
#  'Game console',
#  'Garden or backyard',
#  'Gas oven',
#  'Ground floor access',
#  'Gym',
#  'HBO GO',
#  'Hair Dryer',
#  'Hammock',
#  'Handheld shower head',
#  'Hangers',
#  'Heat lamps',
#  'Heated floors',
#  'Heated towel rack',
#  'Heating',
#  'High chair',
#  'High-resolution computer monitor',
#  'Host greets you',
#  'Hot Tub',
#  'Hot water',
#  'Hot water kettle',
#  'Indoor Fireplace',
#  'Internet',
#  'Iron',
#  'Jetted tub',
#  'Keypad',
#  'Kitchen',
#  'Kitchenette',
#  'Lake access',
#  'Laptop Friendly Workspace',
#  'Lock on Bedroom Door',
#  'Lockbox',
#  'Long term stays allowed',
#  'Luggage dropoff allowed',
#  'Memory foam mattress',
#  'Microwave',
#  'Mini fridge',
#  'Misting system',
#  'Mobile hoist',
#  'Mountain view',
#  'Mudroom',
#  'Murphy bed',
#  'Netflix',
#  'Other',
#  'Other pet(s)',
#  'Outdoor kitchen',
#  'Outdoor parking',
#  'Outdoor seating',
#  'Outlet covers',
#  'Oven',
#  'Pack ’n Play/travel crib',
#  'Paid parking off premises',
#  'Paid parking on premises',
#  'Patio or balcony',
#  'Pets Allowed',
#  'Pets live on this property',
#  'Pillow-top mattress',
#  'Pocket wifi',
#  'Pool',
#  'Pool cover',
#  'Pool toys',
#  'Pool with pool hoist',
#  'Printer',
#  'Private bathroom',
#  'Private entrance',
#  'Private gym',
#  'Private hot tub',
#  'Private living room',
#  'Private pool',
#  'Projector and screen',
#  'Rain shower',
#  'Refrigerator',
#  'Roll-in shower',
#  'Roll-in shower with chair',
#  'Room-darkening shades',
#  'Safety Card',
#  'Sauna',
#  'Self Check-In',
#  'Shampoo',
#  'Shared gym',
#  'Shared hot tub',
#  'Shared pool',
#  'Shower chair',
#  'Single level home',
#  'Ski-in/Ski-out',
#  'Smart TV',
#  'Smart lock',
#  'Smoke Detector',
#  'Smoking Allowed',
#  'Soaking tub',
#  'Sound system',
#  'Stair gates',
#  'Stand alone steam shower',
#  'Standing valet',
#  'Steam oven',
#  'Step-free access',
#  'Stove',
#  'Suitable for Events',
#  'Sun loungers',
#  'TV',
#  'Table corner guards',
#  'Tennis court',
#  'Terrace',
#  'Toilet paper',
#  'Touchless faucets',
#  'Walk-in shower',
#  'Warming drawer',
#  'Washer',
#  'Washer / Dryer',
#  'Waterfront',
#  'Well-lit path to entrance',
#  'Wheelchair Accessible',
#  'Wide clearance to bed',
#  'Wide clearance to shower',
#  'Wide doorway',
#  'Wide entryway',
#  'Wide hallway clearance',
#  'Wifi',
#  'Window guards',
#  'Wine cooler',
#  'Wireless Internet']

# %%
def has_feature(series, feature):
    """ returns a pandas series that includes True or False based
        on whether that entry in the dataframe has that amenity
    """
    col = []
    for ls in series:
        try:
            if feature in ls:
                col.append(True)
            else:
                col.append(False)
        except:
            col.append(False)
    col = pd.Series(col)
    return col

# %%
# create a new column in listings for each amenity
for amenity in unique_amenities:
    col_name = 'has_' + amenity.replace(' ', '_')
    
    # if that listing has that amenity, True, if not, False
    try:
        listings[col_name] = has_feature(listings.amenities, amenity)
    except TypeError: # is a null value
        pass

# %%
# drop blank column and old amenities column
listings = listings.drop(columns=['has_', 'amenities'])

# %%
# inspect dataframe for new columns
listings.head(1)
# Out:
#   access accommodates  availability_30 availability_365 availability_60  \
# 0    NaN            2             30.0              365              60
#
#    availability_90 bathrooms  bed_type  bedrooms  beds  \
# 0             90.0         1  Real Bed       1.0   1.0
#
#   calculated_host_listings_count calendar_last_scraped calendar_updated  \
# 0                              1            2015-07-28     6 months ago
#
#   cancellation_policy     city  cleaning_fee_USD        country country_code  \
# 0            moderate  Arcadia              10.0  United States           US
#
#   date_recorded                                        description  \
# 0    2015-07-25  安靜舒適的独立大套房. 阳光明媚的大卧室，(附帶冰箱)一个超大衣帽間和浴室. 提供免费无线高...
#
#   experiences_offered  extra_people_USD first_review guests_included  \
# 0                none              20.0   2014-09-15               1
#
#    has_availability host_about  host_acceptance_rate_percentage  \
# 0              True        NaN                            100.0
#
#    host_has_profile_pic   host_id  host_identity_verified  host_is_superhost  \
# 0                  True  20130073                   False              False
#
#    host_listings_count host_location host_name host_neighbourhood  \
# 0                  1.0            PH      Cici                NaN
#
#                                     host_picture_url  \
# 0  https://a2.muscache.com/ac/users/20130073/prof...
#
#    host_response_rate_percentage host_response_time  host_since  \
# 0                          100.0       within a day  2014-08-16
#
#                                   host_thumbnail_url  \
# 0  https://a2.muscache.com/ac/users/20130073/prof...
#
#    host_total_listings_count                                    host_url  \
# 0                        1.0  https://www.airbnb.com/users/show/20130073
#
#               host_verifications house_rules       id  instant_bookable  \
# 0  ['email', 'phone', 'reviews']         NaN  3890624             False
#
#   interaction  is_business_travel_ready  is_location_exact jurisdiction_names  \
# 0         NaN                     False               True                NaN
#
#   last_review last_scraped   latitude license  \
# 0  2014-11-02   2015-07-28  34.132812     NaN
#
#                             listing_url   longitude       market  \
# 0  https://www.airbnb.com/rooms/3890624 -118.025147  Los Angeles
#
#    maximum_nights                                         medium_url  \
# 0          1125.0  https://a0.muscache.com/ac/pictures/52102815/8...
#
#   minimum_nights  monthly_price_USD                                 name  \
# 0              1                NaN  安靜舒適的独立大套房,非常适合专业商務人士，学生，实习，渡假遊學...
#
#        neighborhood_overview neighbourhood neighbourhood_cleansed  \
# 0  风景秀丽，豪宅林立，闹中取静，交通方便，华人超市!           NaN                Arcadia
#
#    neighbourhood_group_cleansed                       notes number_of_reviews  \
# 0                           NaN  无合约要求，适合短期旅游，探亲访友，随时拎包入住，                  2
#
#                                          picture_url  price_USD property_type  \
# 0  https://a0.muscache.com/ac/pictures/52102815/8...       90.0         House
#
#    require_guest_phone_verification  require_guest_profile_picture  \
# 0                             False                          False
#
#    requires_license  review_scores_accuracy  review_scores_checkin  \
# 0             False                    10.0                   10.0
#
#    review_scores_cleanliness  review_scores_communication  \
# 0                        8.0                         10.0
#
#    review_scores_location  review_scores_rating  review_scores_value  \
# 0                    10.0                  90.0                  8.0
#
#    reviews_per_month     room_type     scrape_id  security_deposit_USD  \
# 0               0.19  Private room  2.015073e+13                   NaN
#
#   smart_location                                   space  square_feet state  \
# 0            NaN  安靜舒適的独立大套房. 阳光明媚的大卧室，(附帶冰箱)一个超大衣帽間和浴室.          NaN    CA
#
#                                               street  \
# 0  South 2nd Avenue, Arcadia, CA 91006, United St...
#
#                                              summary  \
# 0  我們j位於Arcadia市中心,非常适合专业商務人士，学生，渡假遊學...鄰近高速公路,餐厅...
#
#                                        thumbnail_url  \
# 0  https://a0.muscache.com/ac/pictures/52102815/8...
#
#                                              transit  weekly_price_USD  \
# 0  聚集高尔夫球场，网球场，大型购物中心，影院，图书馆，大型街心公园，跑马场，医院，诊所。非常便...             650.0
#
#                                       xl_picture_url  zipcode has__toilet  \
# 0  https://a0.muscache.com/ac/pictures/52102815/8...  91006.0       False
#
#   has_24-Hour_Check-in has_Accessible-height_bed has_Accessible-height_toilet  \
# 0                False                     False                        False
#
#   has_Air_Conditioning has_Air_purifier has_Alfresco_bathtub has_Amazon_Echo  \
# 0                 True            False                False           False
#
#   has_BBQ_grill has_Baby_bath has_Baby_monitor has_Babysitter_recommendations  \
# 0         False         False            False                          False
#
#   has_Balcony has_Bath_towel has_Bathroom_essentials has_Bathtub  \
# 0       False          False                   False       False
#
#   has_Bathtub_with_bath_chair has_Beach_essentials has_Beach_view  \
# 0                       False                False          False
#
#   has_Beachfront has_Bed_linens has_Bedroom_comforts has_Bidet has_Body_soap  \
# 0          False          False                False     False         False
#
#   has_Breakfast has_Breakfast_table has_Brick_oven has_Building_staff  \
# 0         False               False          False              False
#
#   has_Buzzer/Wireless_Intercom has_Cable_TV has_Carbon_Monoxide_Detector  \
# 0                        False        False                         True
#
#   has_Cardon_Monoxide_Detector has_Cat(s) has_Ceiling_fan has_Ceiling_hoist  \
# 0                        False      False           False             False
#
#   has_Central_air_conditioning has_Changing_table  \
# 0                        False              False
#
#   has_Children’s_books_and_toys has_Children’s_dinnerware  \
# 0                         False                     False
#
#   has_Cleaning_before_checkout has_Coffee_maker has_Convection_oven  \
# 0                        False            False               False
#
#   has_Cooking_basics has_Crib has_DVD_player has_Day_bed  \
# 0              False    False          False       False
#
#   has_Disabled_parking_spot has_Dishes_and_silverware has_Dishwasher  \
# 0                     False                     False          False
#
#   has_Dog(s) has_Doorman has_Double_oven has_Dryer has_EV_charger  \
# 0      False       False           False      True          False
#
#   has_Electric_profiling_bed has_Elevator has_En_suite_bathroom  \
# 0                      False        False                 False
#
#   has_Espresso_machine has_Essentials has_Ethernet_connection  \
# 0                False           True                   False
#
#   has_Exercise_equipment has_Extra_pillows_and_blankets  \
# 0                  False                          False
#
#   has_Family/Kid_Friendly has_Fax_machine has_Fire_Extinguisher has_Fire_pit  \
# 0                   False           False                  True        False
#
#   has_Fireplace_guards has_Firm_mattress has_First_Aid_Kit  \
# 0                False             False              True
#
#   has_Fixed_grab_bars_for_shower has_Fixed_grab_bars_for_toilet  \
# 0                          False                          False
#
#   has_Flat_path_to_front_door has_Formal_dining_area  \
# 0                       False                  False
#
#   has_Free_Parking_on_Premises has_Free_parking_on_street  \
# 0                        False                      False
#
#   has_Free_street_parking has_Front_desk/doorperson has_Full_kitchen  \
# 0                   False                     False            False
#
#   has_Game_console has_Garden_or_backyard has_Gas_oven  \
# 0            False                  False        False
#
#   has_Ground_floor_access has_Gym has_HBO_GO has_Hair_Dryer has_Hammock  \
# 0                   False   False      False          False       False
#
#   has_Handheld_shower_head has_Hangers has_Heat_lamps has_Heated_floors  \
# 0                    False       False          False             False
#
#   has_Heated_towel_rack has_Heating has_High_chair  \
# 0                 False        True          False
#
#   has_High-resolution_computer_monitor has_Host_greets_you has_Hot_Tub  \
# 0                                False               False        True
#
#   has_Hot_water has_Hot_water_kettle has_Indoor_Fireplace has_Internet  \
# 0         False                False                 True         True
#
#   has_Iron has_Jetted_tub has_Keypad has_Kitchen has_Kitchenette  \
# 0    False          False      False       False           False
#
#   has_Lake_access has_Laptop_Friendly_Workspace has_Lock_on_Bedroom_Door  \
# 0           False                         False                    False
#
#   has_Lockbox has_Long_term_stays_allowed has_Luggage_dropoff_allowed  \
# 0       False                       False                       False
#
#   has_Memory_foam_mattress has_Microwave has_Mini_fridge has_Misting_system  \
# 0                    False         False           False              False
#
#   has_Mobile_hoist has_Mountain_view has_Mudroom has_Murphy_bed has_Netflix  \
# 0            False             False       False          False       False
#
#   has_Other has_Other_pet(s) has_Outdoor_kitchen has_Outdoor_parking  \
# 0     False            False               False               False
#
#   has_Outdoor_seating has_Outlet_covers has_Oven has_Pack_’n_Play/travel_crib  \
# 0               False             False    False                        False
#
#   has_Paid_parking_off_premises has_Paid_parking_on_premises  \
# 0                         False                        False
#
#   has_Patio_or_balcony has_Pets_Allowed has_Pets_live_on_this_property  \
# 0                False            False                          False
#
#   has_Pillow-top_mattress has_Pocket_wifi has_Pool has_Pool_cover  \
# 0                   False           False    False          False
#
#   has_Pool_toys has_Pool_with_pool_hoist has_Printer has_Private_bathroom  \
# 0         False                    False       False                False
#
#   has_Private_entrance has_Private_gym has_Private_hot_tub  \
# 0                False           False               False
#
#   has_Private_living_room has_Private_pool has_Projector_and_screen  \
# 0                   False            False                    False
#
#   has_Rain_shower has_Refrigerator has_Roll-in_shower  \
# 0           False            False              False
#
#   has_Roll-in_shower_with_chair has_Room-darkening_shades has_Safety_Card  \
# 0                         False                     False           False
#
#   has_Sauna has_Self_Check-In has_Shampoo has_Shared_gym has_Shared_hot_tub  \
# 0     False             False        True          False              False
#
#   has_Shared_pool has_Shower_chair has_Single_level_home has_Ski-in/Ski-out  \
# 0           False            False                 False              False
#
#   has_Smart_TV has_Smart_lock has_Smoke_Detector has_Smoking_Allowed  \
# 0        False          False               True               False
#
#   has_Soaking_tub has_Sound_system has_Stair_gates  \
# 0           False            False           False
#
#   has_Stand_alone_steam_shower has_Standing_valet has_Steam_oven  \
# 0                        False              False          False
#
#   has_Step-free_access has_Stove has_Suitable_for_Events has_Sun_loungers  \
# 0                False     False                   False            False
#
#   has_TV has_Table_corner_guards has_Tennis_court has_Terrace  \
# 0  False                   False            False       False
#
#   has_Toilet_paper has_Touchless_faucets has_Walk-in_shower  \
# 0            False                 False              False
#
#   has_Warming_drawer has_Washer has_Washer_/_Dryer has_Waterfront  \
# 0              False       True              False          False
#
#   has_Well-lit_path_to_entrance has_Wheelchair_Accessible  \
# 0                         False                     False
#
#   has_Wide_clearance_to_bed has_Wide_clearance_to_shower has_Wide_doorway  \
# 0                     False                        False            False
#
#   has_Wide_entryway has_Wide_hallway_clearance has_Wifi has_Window_guards  \
# 0             False                      False    False             False
#
#   has_Wine_cooler has_Wireless_Internet
# 0           False                  True

# %% [markdown]
# #### Host Verifications
# listings.host_verifications.value_counts(dropna=False).sort_index()

# %%
listings.host_verifications.head()
# Out:
# 0             ['email', 'phone', 'reviews']
# 1                        ['email', 'phone']
# 3    ['email', 'phone', 'reviews', 'jumio']
# 4    ['email', 'phone', 'reviews', 'jumio']
# 5     ['email', 'phone', 'linkedin', 'kba']
# Name: host_verifications, dtype: object

# %%
type(listings.host_verifications[0])
# Out:
# str

# %%
#remove extra characters
listings['host_verifications'] = listings['host_verifications'].str.replace('[','')\
                                                               .str.replace(']','')\
                                                               .str.replace("'",'')\
                                                               .str.replace(" ",'')

# %%
listings.host_verifications.value_counts(dropna=False).sort_index()
# Out:
#                                                                                                               201
# None                                                                                                          241
# email                                                                                                         835
# email,amex,reviews                                                                                              4
# email,facebook                                                                                                 44
# email,facebook,google                                                                                           3
# email,facebook,google,jumio                                                                                     1
# email,facebook,google,linkedin,kba                                                                              1
# email,facebook,google,linkedin,reviews,jumio                                                                    6
# email,facebook,google,reviews,jumio                                                                             1
# email,facebook,google,reviews,jumio,offline_government_id,government_id                                         2
# email,facebook,google,reviews,kba                                                                               2
# email,facebook,google,reviews,kba,work_email                                                                    3
# email,facebook,jumio                                                                                            1
# email,facebook,jumio,government_id                                                                              1
# email,facebook,jumio,kba                                                                                       15
# email,facebook,jumio,offline_government_id,government_id                                                        2
# email,facebook,kba                                                                                              7
# email,facebook,reviews                                                                                         43
# email,facebook,reviews,jumio                                                                                   52
# email,facebook,reviews,jumio,government_id                                                                     89
# email,facebook,reviews,jumio,government_id,work_email                                                           2
# email,facebook,reviews,jumio,offline_government_id,government_id                                               11
# email,facebook,reviews,jumio,offline_government_id,government_id,work_email                                    11
# email,facebook,reviews,jumio,offline_government_id,kba,government_id                                           17
# email,facebook,reviews,jumio,offline_government_id,kba,selfie,government_id,identity_manual                     3
# email,facebook,reviews,jumio,offline_government_id,selfie,government_id,identity_manual                        21
# email,facebook,reviews,kba                                                                                     59
# email,facebook,reviews,kba,work_email                                                                           3
# email,facebook,reviews,offline_government_id,kba,government_id                                                  2
#                                                                                                             ...
# phone,reviews,kba,work_email                                                                                  120
# phone,reviews,manual_offline                                                                                    8
# phone,reviews,manual_offline,jumio                                                                              1
# phone,reviews,manual_offline,jumio,offline_government_id,selfie,government_id,identity_manual                   2
# phone,reviews,manual_offline,jumio,offline_government_id,selfie,government_id,identity_manual,work_email        1
# phone,reviews,manual_offline,offline_government_id,government_id                                                3
# phone,reviews,manual_offline,work_email                                                                        28
# phone,reviews,offline_government_id,government_id                                                              22
# phone,reviews,offline_government_id,kba,government_id                                                           9
# phone,reviews,offline_government_id,kba,government_id,work_email                                                1
# phone,reviews,offline_government_id,kba,selfie,government_id,identity_manual                                   10
# phone,reviews,offline_government_id,kba,selfie,government_id,identity_manual,work_email                         4
# phone,reviews,offline_government_id,selfie,government_id                                                        7
# phone,reviews,offline_government_id,selfie,government_id,identity_manual                                       88
# phone,reviews,selfie                                                                                            9
# phone,reviews,weibo                                                                                             4
# phone,reviews,weibo,jumio                                                                                       2
# phone,reviews,weibo,jumio,offline_government_id,selfie,government_id,identity_manual                            3
# phone,reviews,work_email                                                                                       56
# phone,reviews,zhima_selfie                                                                                     18
# phone,selfie                                                                                                    1
# phone,weibo                                                                                                    24
# phone,work_email                                                                                               63
# phone,zhima_selfie                                                                                            162
# reviews                                                                                                        87
# reviews,jumio,government_id                                                                                     3
# reviews,jumio,offline_government_id,selfie,government_id,identity_manual                                       24
# reviews,kba                                                                                                     3
# weibo                                                                                                           5
# NaN                                                                                                         14230
# Name: host_verifications, Length: 1122, dtype: int64

# %%
# create a set of unique verifications from the Series
unique_ver = set()

for entry in listings.host_verifications:
    try:
        ver_list = entry.split(',')
        for ver in ver_list:
            unique_ver.add(ver)
    except AttributeError:
        pass

unique_ver = list(unique_ver)
unique_ver.sort()
print(unique_ver)
# Out:
# ['', 'None', 'amex', 'email', 'facebook', 'google', 'government_id', 'identity_manual', 'jumio', 'kba', 'linkedin', 'manual_offline', 'manual_online', 'offline_government_id', 'phone', 'photographer', 'reviews', 'selfie', 'sent_id', 'sesame', 'sesame_offline', 'weibo', 'work_email', 'zhima_selfie']

# %%
listings['host_verifications'] = listings['host_verifications'].str.split(',')

# %%
listings['host_verifications'].head()
# Out:
# 0           [email, phone, reviews]
# 1                    [email, phone]
# 3    [email, phone, reviews, jumio]
# 4    [email, phone, reviews, jumio]
# 5     [email, phone, linkedin, kba]
# Name: host_verifications, dtype: object

# %%
type(listings['host_verifications'][0])
# Out:
# list

# %%
# create a new column in listings for each verification
for ver in unique_ver:
    col_name = ver + '_verification'
    
    # if that listing has that verification, True, if not, False
    try:
        listings[col_name] = has_feature(listings.host_verifications, ver)
    except TypeError: # is a null value
        pass

# %%
# drop blank column and old verification column
listings = listings.drop(columns=['_verification', 'host_verifications'])

# %%
# inspect dataframe for new columns
listings.head(1)
# Out:
#   access accommodates  availability_30 availability_365 availability_60  \
# 0    NaN            2             30.0              365              60
#
#    availability_90 bathrooms  bed_type  bedrooms  beds  \
# 0             90.0         1  Real Bed       1.0   1.0
#
#   calculated_host_listings_count calendar_last_scraped calendar_updated  \
# 0                              1            2015-07-28     6 months ago
#
#   cancellation_policy     city  cleaning_fee_USD        country country_code  \
# 0            moderate  Arcadia              10.0  United States           US
#
#   date_recorded                                        description  \
# 0    2015-07-25  安靜舒適的独立大套房. 阳光明媚的大卧室，(附帶冰箱)一个超大衣帽間和浴室. 提供免费无线高...
#
#   experiences_offered  extra_people_USD first_review guests_included  \
# 0                none              20.0   2014-09-15               1
#
#    has_availability host_about  host_acceptance_rate_percentage  \
# 0              True        NaN                            100.0
#
#    host_has_profile_pic   host_id  host_identity_verified  host_is_superhost  \
# 0                  True  20130073                   False              False
#
#    host_listings_count host_location host_name host_neighbourhood  \
# 0                  1.0            PH      Cici                NaN
#
#                                     host_picture_url  \
# 0  https://a2.muscache.com/ac/users/20130073/prof...
#
#    host_response_rate_percentage host_response_time  host_since  \
# 0                          100.0       within a day  2014-08-16
#
#                                   host_thumbnail_url  \
# 0  https://a2.muscache.com/ac/users/20130073/prof...
#
#    host_total_listings_count                                    host_url  \
# 0                        1.0  https://www.airbnb.com/users/show/20130073
#
#   house_rules       id  instant_bookable interaction  \
# 0         NaN  3890624             False         NaN
#
#    is_business_travel_ready  is_location_exact jurisdiction_names last_review  \
# 0                     False               True                NaN  2014-11-02
#
#   last_scraped   latitude license                           listing_url  \
# 0   2015-07-28  34.132812     NaN  https://www.airbnb.com/rooms/3890624
#
#     longitude       market  maximum_nights  \
# 0 -118.025147  Los Angeles          1125.0
#
#                                           medium_url minimum_nights  \
# 0  https://a0.muscache.com/ac/pictures/52102815/8...              1
#
#    monthly_price_USD                                 name  \
# 0                NaN  安靜舒適的独立大套房,非常适合专业商務人士，学生，实习，渡假遊學...
#
#        neighborhood_overview neighbourhood neighbourhood_cleansed  \
# 0  风景秀丽，豪宅林立，闹中取静，交通方便，华人超市!           NaN                Arcadia
#
#    neighbourhood_group_cleansed                       notes number_of_reviews  \
# 0                           NaN  无合约要求，适合短期旅游，探亲访友，随时拎包入住，                  2
#
#                                          picture_url  price_USD property_type  \
# 0  https://a0.muscache.com/ac/pictures/52102815/8...       90.0         House
#
#    require_guest_phone_verification  require_guest_profile_picture  \
# 0                             False                          False
#
#    requires_license  review_scores_accuracy  review_scores_checkin  \
# 0             False                    10.0                   10.0
#
#    review_scores_cleanliness  review_scores_communication  \
# 0                        8.0                         10.0
#
#    review_scores_location  review_scores_rating  review_scores_value  \
# 0                    10.0                  90.0                  8.0
#
#    reviews_per_month     room_type     scrape_id  security_deposit_USD  \
# 0               0.19  Private room  2.015073e+13                   NaN
#
#   smart_location                                   space  square_feet state  \
# 0            NaN  安靜舒適的独立大套房. 阳光明媚的大卧室，(附帶冰箱)一个超大衣帽間和浴室.          NaN    CA
#
#                                               street  \
# 0  South 2nd Avenue, Arcadia, CA 91006, United St...
#
#                                              summary  \
# 0  我們j位於Arcadia市中心,非常适合专业商務人士，学生，渡假遊學...鄰近高速公路,餐厅...
#
#                                        thumbnail_url  \
# 0  https://a0.muscache.com/ac/pictures/52102815/8...
#
#                                              transit  weekly_price_USD  \
# 0  聚集高尔夫球场，网球场，大型购物中心，影院，图书馆，大型街心公园，跑马场，医院，诊所。非常便...             650.0
#
#                                       xl_picture_url  zipcode has__toilet  \
# 0  https://a0.muscache.com/ac/pictures/52102815/8...  91006.0       False
#
#   has_24-Hour_Check-in has_Accessible-height_bed has_Accessible-height_toilet  \
# 0                False                     False                        False
#
#   has_Air_Conditioning has_Air_purifier has_Alfresco_bathtub has_Amazon_Echo  \
# 0                 True            False                False           False
#
#   has_BBQ_grill has_Baby_bath has_Baby_monitor has_Babysitter_recommendations  \
# 0         False         False            False                          False
#
#   has_Balcony has_Bath_towel has_Bathroom_essentials has_Bathtub  \
# 0       False          False                   False       False
#
#   has_Bathtub_with_bath_chair has_Beach_essentials has_Beach_view  \
# 0                       False                False          False
#
#   has_Beachfront has_Bed_linens has_Bedroom_comforts has_Bidet has_Body_soap  \
# 0          False          False                False     False         False
#
#   has_Breakfast has_Breakfast_table has_Brick_oven has_Building_staff  \
# 0         False               False          False              False
#
#   has_Buzzer/Wireless_Intercom has_Cable_TV has_Carbon_Monoxide_Detector  \
# 0                        False        False                         True
#
#   has_Cardon_Monoxide_Detector has_Cat(s) has_Ceiling_fan has_Ceiling_hoist  \
# 0                        False      False           False             False
#
#   has_Central_air_conditioning has_Changing_table  \
# 0                        False              False
#
#   has_Children’s_books_and_toys has_Children’s_dinnerware  \
# 0                         False                     False
#
#   has_Cleaning_before_checkout has_Coffee_maker has_Convection_oven  \
# 0                        False            False               False
#
#   has_Cooking_basics has_Crib has_DVD_player has_Day_bed  \
# 0              False    False          False       False
#
#   has_Disabled_parking_spot has_Dishes_and_silverware has_Dishwasher  \
# 0                     False                     False          False
#
#   has_Dog(s) has_Doorman has_Double_oven has_Dryer has_EV_charger  \
# 0      False       False           False      True          False
#
#   has_Electric_profiling_bed has_Elevator has_En_suite_bathroom  \
# 0                      False        False                 False
#
#   has_Espresso_machine has_Essentials has_Ethernet_connection  \
# 0                False           True                   False
#
#   has_Exercise_equipment has_Extra_pillows_and_blankets  \
# 0                  False                          False
#
#   has_Family/Kid_Friendly has_Fax_machine has_Fire_Extinguisher has_Fire_pit  \
# 0                   False           False                  True        False
#
#   has_Fireplace_guards has_Firm_mattress has_First_Aid_Kit  \
# 0                False             False              True
#
#   has_Fixed_grab_bars_for_shower has_Fixed_grab_bars_for_toilet  \
# 0                          False                          False
#
#   has_Flat_path_to_front_door has_Formal_dining_area  \
# 0                       False                  False
#
#   has_Free_Parking_on_Premises has_Free_parking_on_street  \
# 0                        False                      False
#
#   has_Free_street_parking has_Front_desk/doorperson has_Full_kitchen  \
# 0                   False                     False            False
#
#   has_Game_console has_Garden_or_backyard has_Gas_oven  \
# 0            False                  False        False
#
#   has_Ground_floor_access has_Gym has_HBO_GO has_Hair_Dryer has_Hammock  \
# 0                   False   False      False          False       False
#
#   has_Handheld_shower_head has_Hangers has_Heat_lamps has_Heated_floors  \
# 0                    False       False          False             False
#
#   has_Heated_towel_rack has_Heating has_High_chair  \
# 0                 False        True          False
#
#   has_High-resolution_computer_monitor has_Host_greets_you has_Hot_Tub  \
# 0                                False               False        True
#
#   has_Hot_water has_Hot_water_kettle has_Indoor_Fireplace has_Internet  \
# 0         False                False                 True         True
#
#   has_Iron has_Jetted_tub has_Keypad has_Kitchen has_Kitchenette  \
# 0    False          False      False       False           False
#
#   has_Lake_access has_Laptop_Friendly_Workspace has_Lock_on_Bedroom_Door  \
# 0           False                         False                    False
#
#   has_Lockbox has_Long_term_stays_allowed has_Luggage_dropoff_allowed  \
# 0       False                       False                       False
#
#   has_Memory_foam_mattress has_Microwave has_Mini_fridge has_Misting_system  \
# 0                    False         False           False              False
#
#   has_Mobile_hoist has_Mountain_view has_Mudroom has_Murphy_bed has_Netflix  \
# 0            False             False       False          False       False
#
#   has_Other has_Other_pet(s) has_Outdoor_kitchen has_Outdoor_parking  \
# 0     False            False               False               False
#
#   has_Outdoor_seating has_Outlet_covers has_Oven has_Pack_’n_Play/travel_crib  \
# 0               False             False    False                        False
#
#   has_Paid_parking_off_premises has_Paid_parking_on_premises  \
# 0                         False                        False
#
#   has_Patio_or_balcony has_Pets_Allowed has_Pets_live_on_this_property  \
# 0                False            False                          False
#
#   has_Pillow-top_mattress has_Pocket_wifi has_Pool has_Pool_cover  \
# 0                   False           False    False          False
#
#   has_Pool_toys has_Pool_with_pool_hoist has_Printer has_Private_bathroom  \
# 0         False                    False       False                False
#
#   has_Private_entrance has_Private_gym has_Private_hot_tub  \
# 0                False           False               False
#
#   has_Private_living_room has_Private_pool has_Projector_and_screen  \
# 0                   False            False                    False
#
#   has_Rain_shower has_Refrigerator has_Roll-in_shower  \
# 0           False            False              False
#
#   has_Roll-in_shower_with_chair has_Room-darkening_shades has_Safety_Card  \
# 0                         False                     False           False
#
#   has_Sauna has_Self_Check-In has_Shampoo has_Shared_gym has_Shared_hot_tub  \
# 0     False             False        True          False              False
#
#   has_Shared_pool has_Shower_chair has_Single_level_home has_Ski-in/Ski-out  \
# 0           False            False                 False              False
#
#   has_Smart_TV has_Smart_lock has_Smoke_Detector has_Smoking_Allowed  \
# 0        False          False               True               False
#
#   has_Soaking_tub has_Sound_system has_Stair_gates  \
# 0           False            False           False
#
#   has_Stand_alone_steam_shower has_Standing_valet has_Steam_oven  \
# 0                        False              False          False
#
#   has_Step-free_access has_Stove has_Suitable_for_Events has_Sun_loungers  \
# 0                False     False                   False            False
#
#   has_TV has_Table_corner_guards has_Tennis_court has_Terrace  \
# 0  False                   False            False       False
#
#   has_Toilet_paper has_Touchless_faucets has_Walk-in_shower  \
# 0            False                 False              False
#
#   has_Warming_drawer has_Washer has_Washer_/_Dryer has_Waterfront  \
# 0              False       True              False          False
#
#   has_Well-lit_path_to_entrance has_Wheelchair_Accessible  \
# 0                         False                     False
#
#   has_Wide_clearance_to_bed has_Wide_clearance_to_shower has_Wide_doorway  \
# 0                     False                        False            False
#
#   has_Wide_entryway has_Wide_hallway_clearance has_Wifi has_Window_guards  \
# 0             False                      False    False             False
#
#   has_Wine_cooler has_Wireless_Internet None_verification amex_verification  \
# 0           False                  True             False             False
#
#   email_verification facebook_verification google_verification  \
# 0               True                 False               False
#
#   government_id_verification identity_manual_verification jumio_verification  \
# 0                      False                        False              False
#
#   kba_verification linkedin_verification manual_offline_verification  \
# 0            False                 False                       False
#
#   manual_online_verification offline_government_id_verification  \
# 0                      False                              False
#
#   phone_verification photographer_verification reviews_verification  \
# 0               True                     False                 True
#
#   selfie_verification sent_id_verification sesame_verification  \
# 0               False                False               False
#
#   sesame_offline_verification weibo_verification work_email_verification  \
# 0                       False              False                   False
#
#   zhima_selfie_verification
# 0                     False

# %% [markdown]
# #### Save new listings file

# %%
filename = 'los-angeles_listings.csv'
destination = '/Users/limesncoconuts2/springboard_data/data_capstone_one/los_angeles/'
listings.to_csv(filename, index=False)

# move csv to target directory
current_dir = os.getcwd() + '/' + filename
shutil.move(os.path.join(current_dir), os.path.join(destination, filename))
# Out:
# '/Users/limesncoconuts2/springboard_data/data_capstone_one/los_angeles/los-angeles_listings.csv'

# %% [markdown]
# ### Reviews Data
#
# **Note:** Since one of the cells in this section took **90 hours** to run, I will not be re-running the below cells to keep this notebook in chronological order.

# %% [markdown]
# Checking the number of entries and size of the dataframe:

# %%
# import reviews files for Los Angeles
# add a city column
directory = '/Users/limesncoconuts2/springboard_data/data_capstone_one/los_angeles/'
city = 'los-angeles'
reviews = pd.read_csv(directory + city + '_reviews.csv')
reviews['city_name'] = city

# %%
reviews.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14198249 entries, 0 to 14198248
# Data columns (total 8 columns):
# listing_id       int64
# id               int64
# date             object
# reviewer_id      int64
# reviewer_name    object
# comments         object
# date_recorded    object
# city_name        object
# dtypes: int64(3), object(5)
# memory usage: 8.8 GB

# %%
reviews.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7680552  50209733  2015-10-10     43618076          Paul
# 1     7680552  50521911  2015-10-12     44347928     Dwendalyz
# 2     7680552  53635576  2015-11-10     31371772        Varunn
# 3     7680552  54673483  2015-11-22      2530719          Lina
# 4     7680552  57881891  2015-12-30      2357565          Sage
#
#                                             comments date_recorded  \
# 0          Was a great stay! Host was very helpful.     2017-03-02
# 1  It was a beautiful home. The kitchen view was ...    2017-03-02
# 2  The house is a very beautiful house with a gre...    2017-03-02
# 3  Stunning house ! Very clean and comfortable  i...    2017-03-02
# 4  Servando was easy to get ahold of as well as p...    2017-03-02
#
#      city_name
# 0  los-angeles
# 1  los-angeles
# 2  los-angeles
# 3  los-angeles
# 4  los-angeles

# %% [markdown]
# #### Remove non-English reviews
# Since the sentiment analysis I will do only considers the syntax of English, I will remove rows of the dataframe with non-English reviews:

# %%
start = time.time()
lang = []
for comment in reviews['comments']:
    try:
        lang.append(detect(comment))
    except: #NaN
        lang.append('')

lang = pd.Series(lang)
total_time = (time.time()-start)/3600
print('Time',total_time,'hours')
reviews['language'] = lang.values
lang
# Out:
# Time 90.42469364245733 hours
# 0              en
# 1              en
# 2              en
# 3              en
# 4              en
# 5              en
# 6              en
# 7              en
# 8              en
# 9              en
# 10             en
# 11             en
# 12             en
# 13             en
# 14             en
# 15             en
# 16             en
# 17             en
# 18             en
# 19             en
# 20             en
# 21             en
# 22             en
# 23             en
# 24             en
# 25             en
# 26             en
# 27             en
# 28             en
# 29             en
#             ...
# 14198219       en
# 14198220       en
# 14198221       en
# 14198222       en
# 14198223       en
# 14198224       en
# 14198225       en
# 14198226       en
# 14198227       en
# 14198228       en
# 14198229       en
# 14198230       en
# 14198231       en
# 14198232       en
# 14198233       en
# 14198234       en
# 14198235       en
# 14198236       en
# 14198237       en
# 14198238       en
# 14198239    zh-cn
# 14198240       en
# 14198241       en
# 14198242       tr
# 14198243       en
# 14198244       en
# 14198245       en
# 14198246       en
# 14198247       en
# 14198248       en
# Length: 14198249, dtype: object

# %%
len(reviews)
# Out:
# 14198249

# %%
reviews.language.value_counts(dropna=False)
# Out:
# en       13320062
# fr         178624
# zh-cn      141192
# es         109333
# de         100062
# ko          54482
#             33239
# ro          32754
# pt          27086
# it          26263
# ja          19711
# af          17488
# so          16485
# nl          15383
# sv          14558
# ru          13915
# ca           9416
# no           8261
# da           8088
# cs           7596
# pl           6545
# tl           5915
# zh-tw        5273
# fi           3987
# cy           3056
# hu           2667
# sw           2577
# tr           2402
# vi           2364
# id           2010
# hr           1850
# et           1793
# sl           1199
# sk            897
# th            313
# ar            230
# he            222
# lt            208
# el            198
# sq            196
# bg            124
# lv            113
# uk             52
# mk             44
# hi              8
# te              8
# Name: language, dtype: int64

# %%
# only keep English reviews in the dataframe
reviews = reviews[reviews.language == 'en']

# %%
len(reviews)
# Out:
# 13320062

# %% [markdown]
# #### Change datatypes
# The 'date' column in the reviews data can esily be changes to a datetime datatype:

# %%
reviews['date'] = pd.to_datetime(reviews['date'], format='%Y-%m-%d')

# %% [markdown]
# #### Save File To Computer:
#
# **Note:** I had already saved the reviews file with the language data to the destination folder, however, I wanted to correctly write a cell that would replace the file if it had aleady been created. Therefore, the following cell is run out of order

# %%
# import previous reviews df
reviews = pd.read_csv('/Users/limesncoconuts2/springboard_data/data_capstone_one/los_angeles/los-angeles_reviews.csv')

# save reviews data as csv file
filename = 'los-angeles_reviews.csv'
destination = '/Users/limesncoconuts2/springboard_data/data_capstone_one/los_angeles/'
reviews.to_csv(filename, index=False)

# move csv to target directory
current_dir = os.getcwd() + '/' + filename
shutil.move(os.path.join(current_dir), os.path.join(destination, filename))
# Out:
# '/Users/limesncoconuts2/springboard_data/data_capstone_one/los_angeles/los-angeles_reviews.csv'
